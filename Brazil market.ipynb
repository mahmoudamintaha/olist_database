# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:12345678@localhost:3306/brazil
# Out:
# 'Connected: root@brazil'

# %%
# %sql SHOW TABLES
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 9 rows affected.
# [('category_translation',),
#  ('customers',),
#  ('geolocation',),
#  ('order_items',),
#  ('order_payments',),
#  ('order_reviews',),
#  ('orders',),
#  ('products',),
#  ('sellers',)]

# %% [markdown]
# ### <font color='red'>Desired Schema <font/>
#
# <img src="https://i.imgur.com/HRhd2Y0.png" alt="Desired Schema"/>

# %% [markdown]
# ### ٌRenaming columns to replace spaces with underscores

# %%
# %%sql
# -- using a sql query to write the renaming query
# SELECT CONCAT('ALTER TABLE ', TABLE_NAME, ' RENAME COLUMN ', '`',COLUMN_NAME,'`', ' TO ', REPLACE(COLUMN_NAME, ' ', '_'), ';')
# FROM INFORMATION_SCHEMA.COLUMNS
# WHERE TABLE_SCHEMA = 'brazil';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 50 rows affected.
# [('ALTER TABLE category_translation RENAME COLUMN `product_category_name` TO product_category_name;',),
#  ('ALTER TABLE category_translation RENAME COLUMN `product_category_name_english` TO product_category_name_english;',),
#  ('ALTER TABLE customers RENAME COLUMN `customer_city` TO customer_city;',),
#  ('ALTER TABLE customers RENAME COLUMN `customer_id` TO customer_id;',),
#  ('ALTER TABLE customers RENAME COLUMN `customer_state` TO customer_state;',),
#  ('ALTER TABLE customers RENAME COLUMN `customer_unique_id` TO customer_unique_id;',),
#  ('ALTER TABLE customers RENAME COLUMN `customer_zip_code_prefix` TO customer_zip_code_prefix;',),
#  ('ALTER TABLE geolocation RENAME COLUMN `geolocation city` TO geolocation_city;',),
#  ('ALTER TABLE geolocation RENAME COLUMN `geolocation state` TO geolocation_state;',),
#  ('ALTER TABLE geolocation RENAME COLUMN `geolocation zip code prefix` TO geolocation_zip_code_prefix;',),
#  ('ALTER TABLE order_items RENAME COLUMN `freight value` TO freight_value;',),
#  ('ALTER TABLE order_items RENAME COLUMN `order id` TO order_id;',),
#  ('ALTER TABLE order_items RENAME COLUMN `order item id` TO order_item_id;',),
#  ('ALTER TABLE order_items RENAME COLUMN `price` TO price;',),
#  ('ALTER TABLE order_items RENAME COLUMN `product id` TO product_id;',),
#  ('ALTER TABLE order_items RENAME COLUMN `seller id` TO seller_id;',),
#  ('ALTER TABLE order_items RENAME COLUMN `shipping limit date` TO shipping_limit_date;',),
#  ('ALTER TABLE order_payments RENAME COLUMN `order id` TO order_id;',),
#  ('ALTER TABLE order_payments RENAME COLUMN `payment installments` TO payment_installments;',),
#  ('ALTER TABLE order_payments RENAME COLUMN `payment sequential` TO payment_sequential;',),
#  ('ALTER TABLE order_payments RENAME COLUMN `payment type` TO payment_type;',),
#  ('ALTER TABLE order_payments RENAME COLUMN `payment value` TO payment_value;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `order id` TO order_id;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review answer timestamp` TO review_answer_timestamp;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review comment message` TO review_comment_message;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review comment title` TO review_comment_title;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review creation date` TO review_creation_date;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review id` TO review_id;',),
#  ('ALTER TABLE order_reviews RENAME COLUMN `review score` TO review_score;',),
#  ('ALTER TABLE orders RENAME COLUMN `customer id` TO customer_id;',),
#  ('ALTER TABLE orders RENAME COLUMN `order approved at` TO order_approved_at;',),
#  ('ALTER TABLE orders RENAME COLUMN `order delivered carrier date` TO order_delivered_carrier_date;',),
#  ('ALTER TABLE orders RENAME COLUMN `order delivered customer date` TO order_delivered_customer_date;',),
#  ('ALTER TABLE orders RENAME COLUMN `order estimated delivery date` TO order_estimated_delivery_date;',),
#  ('ALTER TABLE orders RENAME COLUMN `order id` TO order_id;',),
#  ('ALTER TABLE orders RENAME COLUMN `order purchase timestamp` TO order_purchase_timestamp;',),
#  ('ALTER TABLE orders RENAME COLUMN `order status` TO order_status;',),
#  ('ALTER TABLE products RENAME COLUMN `product category name` TO product_category_name;',),
#  ('ALTER TABLE products RENAME COLUMN `product description lenght` TO product_description_lenght;',),
#  ('ALTER TABLE products RENAME COLUMN `product height cm` TO product_height_cm;',),
#  ('ALTER TABLE products RENAME COLUMN `product id` TO product_id;',),
#  ('ALTER TABLE products RENAME COLUMN `product length cm` TO product_length_cm;',),
#  ('ALTER TABLE products RENAME COLUMN `product name lenght` TO product_name_lenght;',),
#  ('ALTER TABLE products RENAME COLUMN `product photos qty` TO product_photos_qty;',),
#  ('ALTER TABLE products RENAME COLUMN `product weight g` TO product_weight_g;',),
#  ('ALTER TABLE products RENAME COLUMN `product width cm` TO product_width_cm;',),
#  ('ALTER TABLE sellers RENAME COLUMN `seller city` TO seller_city;',),
#  ('ALTER TABLE sellers RENAME COLUMN `seller id` TO seller_id;',),
#  ('ALTER TABLE sellers RENAME COLUMN `seller state` TO seller_state;',),
#  ('ALTER TABLE sellers RENAME COLUMN `seller zip code prefix` TO seller_zip_code_prefix;',)]

# %%
# %%sql
#
# ALTER TABLE category_translation RENAME COLUMN `product_category_name` TO product_category_name;
# ALTER TABLE category_translation RENAME COLUMN `product_category_name_english` TO product_category_name_english;
# ALTER TABLE customers RENAME COLUMN `customer_city` TO customer_city;
# ALTER TABLE customers RENAME COLUMN `customer_id` TO customer_id;
# ALTER TABLE customers RENAME COLUMN `customer_state` TO customer_state;
# ALTER TABLE customers RENAME COLUMN `customer_unique_id` TO customer_unique_id;
# ALTER TABLE customers RENAME COLUMN `customer_zip_code_prefix` TO customer_zip_code_prefix;
# ALTER TABLE geolocation RENAME COLUMN `geolocation city` TO geolocation_city;
# ALTER TABLE geolocation RENAME COLUMN `geolocation state` TO geolocation_state;
# ALTER TABLE geolocation RENAME COLUMN `geolocation zip code prefix` TO geolocation_zip_code_prefix;
# ALTER TABLE order_items RENAME COLUMN `freight value` TO freight_value;
# ALTER TABLE order_items RENAME COLUMN `order id` TO order_id;
# ALTER TABLE order_items RENAME COLUMN `order item id` TO order_item_id;
# ALTER TABLE order_items RENAME COLUMN `price` TO price;
# ALTER TABLE order_items RENAME COLUMN `product id` TO product_id;
# ALTER TABLE order_items RENAME COLUMN `seller id` TO seller_id;
# ALTER TABLE order_items RENAME COLUMN `shipping limit date` TO shipping_limit_date;
# ALTER TABLE order_payments RENAME COLUMN `order id` TO order_id;
# ALTER TABLE order_payments RENAME COLUMN `payment installments` TO payment_installments;
# ALTER TABLE order_payments RENAME COLUMN `payment sequential` TO payment_sequential;
# ALTER TABLE order_payments RENAME COLUMN `payment type` TO payment_type;
# ALTER TABLE order_payments RENAME COLUMN `payment value` TO payment_value;
# ALTER TABLE order_reviews RENAME COLUMN `order id` TO order_id;
# ALTER TABLE order_reviews RENAME COLUMN `review answer timestamp` TO review_answer_timestamp;
# ALTER TABLE order_reviews RENAME COLUMN `review comment message` TO review_comment_message;
# ALTER TABLE order_reviews RENAME COLUMN `review comment title` TO review_comment_title;
# ALTER TABLE order_reviews RENAME COLUMN `review creation date` TO review_creation_date;
# ALTER TABLE order_reviews RENAME COLUMN `review id` TO review_id;
# ALTER TABLE order_reviews RENAME COLUMN `review score` TO review_score;
# ALTER TABLE orders RENAME COLUMN `customer id` TO customer_id;
# ALTER TABLE orders RENAME COLUMN `order approved at` TO order_approved_at;
# ALTER TABLE orders RENAME COLUMN `order delivered carrier date` TO order_delivered_carrier_date;
# ALTER TABLE orders RENAME COLUMN `order delivered customer date` TO order_delivered_customer_date;
# ALTER TABLE orders RENAME COLUMN `order estimated delivery date` TO order_estimated_delivery_date;
# ALTER TABLE orders RENAME COLUMN `order id` TO order_id;
# ALTER TABLE orders RENAME COLUMN `order purchase timestamp` TO order_purchase_timestamp;
# ALTER TABLE orders RENAME COLUMN `order status` TO order_status;
# ALTER TABLE products RENAME COLUMN `product category name` TO product_category_name;
# ALTER TABLE products RENAME COLUMN `product description lenght` TO product_description_lenght;
# ALTER TABLE products RENAME COLUMN `product height cm` TO product_height_cm;
# ALTER TABLE products RENAME COLUMN `product id` TO product_id;
# ALTER TABLE products RENAME COLUMN `product length cm` TO product_length_cm;
# ALTER TABLE products RENAME COLUMN `product name lenght` TO product_name_lenght;
# ALTER TABLE products RENAME COLUMN `product photos qty` TO product_photos_qty;
# ALTER TABLE products RENAME COLUMN `product weight g` TO product_weight_g;
# ALTER TABLE products RENAME COLUMN `product width cm` TO product_width_cm;
# ALTER TABLE sellers RENAME COLUMN `seller city` TO seller_city;
# ALTER TABLE sellers RENAME COLUMN `seller id` TO seller_id;
# ALTER TABLE sellers RENAME COLUMN `seller state` TO seller_state;
# ALTER TABLE sellers RENAME COLUMN `seller zip code prefix` TO seller_zip_code_prefix;

# %% [markdown]
# ## Check if the names are correctly changed

# %%
# %%sql
#
# SELECT *
#
# FROM
#     orders
# LIMIT
#     5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('e481f51cbdc54678b7cc49136f2d6af7', '9ef432eb6251297304e76186b10a928d', 'delivered', '2017-10-02 10:56:33', '2017-10-02 11:07:15', '2017-10-04 19:55:00', '2017-10-10 21:25:13', '2017-10-18 00:00:00'),
#  ('53cdb2fc8bc7dce0b6741e2150273451', 'b0830fb4747a6c6d20dea0b8c802d7ef', 'delivered', '2018-07-24 20:41:37', '2018-07-26 03:24:27', '2018-07-26 14:31:00', '2018-08-07 15:27:45', '2018-08-13 00:00:00'),
#  ('47770eb9100c2d0c44946d9cf07ec65d', '41ce2a54c0b03bf3443c3d931a367089', 'delivered', '2018-08-08 08:38:49', '2018-08-08 08:55:23', '2018-08-08 13:50:00', '2018-08-17 18:06:29', '2018-09-04 00:00:00'),
#  ('949d5b44dbf5de918fe9c16f97b45f8a', 'f88197465ea7920adcdbec7375364d82', 'delivered', '2017-11-18 19:28:06', '2017-11-18 19:45:59', '2017-11-22 13:39:59', '2017-12-02 00:28:42', '2017-12-15 00:00:00'),
#  ('ad21c59c0840e6cb83a9ceb5573f8159', '8ab97904e6daea8866dbdbc4fb7aad2c', 'delivered', '2018-02-13 21:18:39', '2018-02-13 22:20:29', '2018-02-14 19:46:34', '2018-02-16 18:17:02', '2018-02-26 00:00:00')]

# %%
# %%sql
#
# -- What makes the customer unique id column include duplicates?
#
# SELECT
#     *
# FROM
#     customers
# WHERE customer_unique_id in (SELECT customer_unique_id FROM customers group by customer_unique_id having count(customer_unique_id) > 5)
# ORDER BY customer_unique_id
#
# LIMIT 25;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 25 rows affected.
# [('a969b9f8d923bc7fd97b578f7c499194', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('ed1793d2d1e4175d5846ce7ebb4a01f5', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('27129ce1ebca4ffa23a049c51cc8ec95', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('588047d7101d88c333691e47659d7099', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('6152d0774bbbf74f7140541c0569dafa', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('c0352e94059e3e5a714c9ad0c8306a54', '12f5d6e1cbf93dafd9dcc19095df0b3d', 82200, 'curitiba', 'PR'),
#  ('53e16f83735cfe02bf83ef6481ca241e', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('95b9cacc4bc81c3a0a33967bcde6fcd8', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('41a16488effb86580d7a89f8aa19a03b', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('c2ff01bd4fa72f9487ee397f6c5989d2', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('fff7466a253c0e59499ea943462c10f9', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('9a4578c9dd9dce6517d583cb5eca0276', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('ee5c2e36a79081c2440e61990ec2f3af', '1b6c7548a2a1f9037c1fd3ddfed95f33', 38301, 'ituiutaba', 'MG'),
#  ('f37a14140ac3a8efbb4d2eab6585edb7', '3e43e6105506432c953e165fb2acf44c', 11701, 'praia grande', 'SP'),
#  ('a4413edae691fd0d28bd04b8a38b259d', '3e43e6105506432c953e165fb2acf44c', 11700, 'praia grande', 'SP'),
#  ('1815fdaaae692479110428598596b5e5', '3e43e6105506432c953e165fb2acf44c', 11701, 'praia grande', 'SP'),
#  ('06ec7aed3161859018db02f695b6600d', '3e43e6105506432c953e165fb2acf44c', 11701, 'praia grande', 'SP'),
#  ('6b92dda6e324283dbe4969c443e3bf1a', '3e43e6105506432c953e165fb2acf44c', 11701, 'praia grande', 'SP'),
#  ('e68e6423401e85c138229b23d4bf4761', '3e43e6105506432c953e165fb2acf44c', 11700, 'praia grande', 'SP'),
#  ('b70f8552b91ef49129519206966e2472', '3e43e6105506432c953e165fb2acf44c', 11700, 'praia grande', 'SP'),
#  ('b63c9cfc5dcb06ed307ca95957fa216c', '3e43e6105506432c953e165fb2acf44c', 11704, 'praia grande', 'SP'),
#  ('2bbd32d4ef14893d2d8c1a0df08403cf', '3e43e6105506432c953e165fb2acf44c', 11701, 'praia grande', 'SP'),
#  ('aa4178995eb97c7a31f3133c5b244651', '47c1a3033b8b77b3ab6e109eb4d5fdf3', 6634, 'jandira', 'SP'),
#  ('880b4294c02c693bb9882858758995d5', '47c1a3033b8b77b3ab6e109eb4d5fdf3', 6624, 'jandira', 'SP'),
#  ('57802b83580aed851828868d4f7a4917', '47c1a3033b8b77b3ab6e109eb4d5fdf3', 6634, 'jandira', 'SP')]

# %% [markdown]
# AS we see the real customer ID is the column named (customer_unique_id), We should invistigate this further.

# %% [markdown]
# After some online invistigation I found out that OLIST system generates a unique id for each customer right after signing up so it's permanent, While generates a random ID every time a cutomer places an order which is stored in customer id.
# We can check this by comparing number of unique orders id and our customer id column from the customers table.

# %%
# %sql SELECT COUNT(distinct customer_id) from customers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99441,)]

# %%
# %sql SELECT COUNT(distinct order_id) from orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99441,)]

# %%
# %sql SELECT * FROM orders limit 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('e481f51cbdc54678b7cc49136f2d6af7', '9ef432eb6251297304e76186b10a928d', 'delivered', '2017-10-02 10:56:33', '2017-10-02 11:07:15', '2017-10-04 19:55:00', '2017-10-10 21:25:13', '2017-10-18 00:00:00'),
#  ('53cdb2fc8bc7dce0b6741e2150273451', 'b0830fb4747a6c6d20dea0b8c802d7ef', 'delivered', '2018-07-24 20:41:37', '2018-07-26 03:24:27', '2018-07-26 14:31:00', '2018-08-07 15:27:45', '2018-08-13 00:00:00'),
#  ('47770eb9100c2d0c44946d9cf07ec65d', '41ce2a54c0b03bf3443c3d931a367089', 'delivered', '2018-08-08 08:38:49', '2018-08-08 08:55:23', '2018-08-08 13:50:00', '2018-08-17 18:06:29', '2018-09-04 00:00:00'),
#  ('949d5b44dbf5de918fe9c16f97b45f8a', 'f88197465ea7920adcdbec7375364d82', 'delivered', '2017-11-18 19:28:06', '2017-11-18 19:45:59', '2017-11-22 13:39:59', '2017-12-02 00:28:42', '2017-12-15 00:00:00'),
#  ('ad21c59c0840e6cb83a9ceb5573f8159', '8ab97904e6daea8866dbdbc4fb7aad2c', 'delivered', '2018-02-13 21:18:39', '2018-02-13 22:20:29', '2018-02-14 19:46:34', '2018-02-16 18:17:02', '2018-02-26 00:00:00')]

# %%
# %sql SELECT COUNT(distinct customer_id) from orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99441,)]

# %%
# %%sql
#
# SELECT * from Orders limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('e481f51cbdc54678b7cc49136f2d6af7', '9ef432eb6251297304e76186b10a928d', 'delivered', '2017-10-02 10:56:33', '2017-10-02 11:07:15', '2017-10-04 19:55:00', '2017-10-10 21:25:13', '2017-10-18 00:00:00'),
#  ('53cdb2fc8bc7dce0b6741e2150273451', 'b0830fb4747a6c6d20dea0b8c802d7ef', 'delivered', '2018-07-24 20:41:37', '2018-07-26 03:24:27', '2018-07-26 14:31:00', '2018-08-07 15:27:45', '2018-08-13 00:00:00'),
#  ('47770eb9100c2d0c44946d9cf07ec65d', '41ce2a54c0b03bf3443c3d931a367089', 'delivered', '2018-08-08 08:38:49', '2018-08-08 08:55:23', '2018-08-08 13:50:00', '2018-08-17 18:06:29', '2018-09-04 00:00:00'),
#  ('949d5b44dbf5de918fe9c16f97b45f8a', 'f88197465ea7920adcdbec7375364d82', 'delivered', '2017-11-18 19:28:06', '2017-11-18 19:45:59', '2017-11-22 13:39:59', '2017-12-02 00:28:42', '2017-12-15 00:00:00'),
#  ('ad21c59c0840e6cb83a9ceb5573f8159', '8ab97904e6daea8866dbdbc4fb7aad2c', 'delivered', '2018-02-13 21:18:39', '2018-02-13 22:20:29', '2018-02-14 19:46:34', '2018-02-16 18:17:02', '2018-02-26 00:00:00')]

# %% [markdown]
# Looking for the previous resultset and checking the schema picture I provided above now I know that Customer.customer_id
# is used only to connect etween customers and orders tables. I thought about dropping orders.oreder_id and using orders.customer_id to connect the orders table to other tables too But that's unneccesary effort. I'll keep everything as it is.
# <font color='green'> <b> But keep in mind that any customer aggragation will be done using customer.customer_unique_id.<b/><font/>

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# # <FONT color = 'red'>Check the integrity of columns nominated to be primary keys<FONT/>

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color = 'green'>1- Customers table<FONT/>

# %%
# %sql describe customers
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('customer_id', 'varchar(32)', 'NO', '', None, ''),
#  ('customer_unique_id', 'varchar(32)', 'NO', '', None, ''),
#  ('customer_zip_code_prefix', 'int', 'NO', '', None, ''),
#  ('customer_city', 'varchar(32)', 'NO', '', None, ''),
#  ('customer_state', 'varchar(2)', 'NO', '', None, '')]

# %%
# %sql SELECT COUNT(customer_id), COUNT(distinct customer_id) FROM customers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99441, 99441)]

# %%
# Now I'm creating a primary key for the custoers table
# %sql Alter table customers ADD primary key (customer_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>2- Orders table<FONT/>

# %%
# %sql Describe orders; -- Checking for keys
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 8 rows affected.
# [('order_id', 'varchar(32)', 'NO', '', None, ''),
#  ('customer_id', 'varchar(32)', 'NO', '', None, ''),
#  ('order_status', 'varchar(11)', 'NO', '', None, ''),
#  ('order_purchase_timestamp', 'varchar(19)', 'NO', '', None, ''),
#  ('order_approved_at', 'varchar(19)', 'YES', '', None, ''),
#  ('order_delivered_carrier_date', 'varchar(19)', 'YES', '', None, ''),
#  ('order_delivered_customer_date', 'varchar(19)', 'YES', '', None, ''),
#  ('order_estimated_delivery_date', 'varchar(19)', 'NO', '', None, '')]

# %%
# %sql SELECT COUNT(order_id), COUNT(distinct order_id) FROM orders;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99441, 99441)]

# %%
# Now I'm creating a primary key for the Orders table
# %sql Alter table orders ADD primary key (order_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>3- Geo table<FONT/>

# %%
# %sql Describe geolocation;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 3 rows affected.
# [('geolocation_zip_code_prefix', 'int', 'NO', '', None, ''),
#  ('geolocation_city', 'varchar(38)', 'NO', '', None, ''),
#  ('geolocation_state', 'varchar(2)', 'NO', '', None, '')]

# %%
# %%sql
# SELECT
#     Count(geolocation_zip_code_prefix),
#     COUNT(distinct geolocation_zip_code_prefix),
#     COUNT(distinct geolocation_zip_code_prefix, geolocation_city, geolocation_state)
# FROM
#     geolocation;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(1000163, 19015, 19617)]

# %% [markdown]
# Wow, That's a huge amount of duplicates. As you see there are 19617 unique compinations of all columns but the table has over
# <font color='red'> one million </font> row.
# Lets remove those extra rows. We'll do that by creating another table containing the unique compinations only.

# %%
# %%sql
#
# CREATE TABLE geo AS(
# SELECT
#     geolocation_zip_code_prefix,
#     MAX(geolocation_city),
#     MAX(geolocation_state)
#
# FROM
#     geolocation
#
# GROUP BY
#     geolocation_zip_code_prefix
# );

# %%
# %%sql
#
# SELECT
#     COUNT(*)
#
# FROM
#     geo;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(19015,)]

# %%
#Let's drop the old table
# %sql DROP TABLE geolocation;

# %%
# %sql Describe geo;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 3 rows affected.
# [('geolocation_zip_code_prefix', 'int', 'NO', '', None, ''),
#  ('MAX(geolocation_city)', 'varchar(38)', 'YES', '', None, ''),
#  ('MAX(geolocation_state)', 'varchar(2)', 'YES', '', None, '')]

# %%
# %%sql
# ALTER TABLE geo
# RENAME TO geolocation;

# %%
# Now I'm creating a primary key for the geolocation table
# %sql Alter table geolocation ADD primary key (geolocation_zip_code_prefix);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>4- Order reviews table<FONT/>

# %%
# %sql SELECT * FROM order_reviews LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('7bc2406110b926393aa56f80a40eba40', '73fc7af87114b39712e6da79b0a377eb', 4, None, None, '2018-01-18 00:00:00', '2018-01-18 21:46:59'),
#  ('80e641a11e56f04c1ad469d5645fdfde', 'a548910a1c6147796b98fdf73dbeba33', 5, None, None, '2018-03-10 00:00:00', '2018-03-11 03:05:13'),
#  ('228ce5500dc1d8e020d8d1322874b6f0', 'f9e4b658b201a9f2ecdecbb34bed034b', 5, None, None, '2018-02-17 00:00:00', '2018-02-18 14:36:24'),
#  ('e64fb393e7b32834bb789ff8bb30750e', '658677c97b385a9be170737859d3511b', 5, None, 'Recebi bem antes do prazo estipulado.', '2017-04-21 00:00:00', '2017-04-21 22:02:06'),
#  ('f7c4243c7fe1938f181bec41a392bdeb', '8e6bfb81e283fa7e4f11123a3fb894f1', 5, None, 'Parabéns lojas lannister adorei comprar pela Internet seguro e prático Parabéns a todos feliz Páscoa', '2018-03-01 00:00:00', '2018-03-02 10:26:53')]

# %%
# %%sql
# SELECT
#     count(review_id), count(Distinct review_id)
# FROM
#     order_reviews;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(99224, 98410)]

# %%
# %%sql
# -- CHECK for review_id present more than once in the table
# SELECT
#     *
# FROM
#     order_reviews
#
# WHERE
#     review_id IN (
#                     SELECT
#                         review_id
#                     FROM
#                         order_reviews
#                     GROUP BY review_id
#                     HAVING COUNT(review_id) > 1
#                     )
# ORDER BY
#     review_id;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1603 rows affected.
# [('00130cbe1f9d422698c812ed8ded1919', '04a28263e085d399c97ae49e0b477efa', 1, None, 'O cartucho "original HP" 60XL não é reconhecido pela impressora, consequentemente não funcionou. Além de ter chegado com atraso de mais de 15 dias do previsto. Preciso que seja trocado.', '2018-03-07 00:00:00', '2018-03-20 18:08:23'),
#  ('00130cbe1f9d422698c812ed8ded1919', 'dfcdfc43867d1c1381bfaf62d6b9c195', 1, None, 'O cartucho "original HP" 60XL não é reconhecido pela impressora, consequentemente não funcionou. Além de ter chegado com atraso de mais de 15 dias do previsto. Preciso que seja trocado.', '2018-03-07 00:00:00', '2018-03-20 18:08:23'),
#  ('0115633a9c298b6a98bcbe4eee75345f', '0c9850b2c179c1ef60d2855e2751d1fa', 5, None, None, '2017-09-21 00:00:00', '2017-09-26 03:27:47'),
#  ('0115633a9c298b6a98bcbe4eee75345f', '78a4201f58af3463bdab842eea4bc801', 5, None, None, '2017-09-21 00:00:00', '2017-09-26 03:27:47'),
#  ('0174caf0ee5964646040cd94e15ac95e', 'f93a732712407c02dce5dd5088d0f47b', 1, None, 'Produto entregue dentro de embalagem do fornecedor sem os parafusos de fixação das partes.', '2018-03-07 00:00:00', '2018-03-08 03:00:53'),
#  ('0174caf0ee5964646040cd94e15ac95e', '74db91e33b4e1fd865356c89a61abf1f', 1, None, 'Produto entregue dentro de embalagem do fornecedor sem os parafusos de fixação das partes.', '2018-03-07 00:00:00', '2018-03-08 03:00:53'),
#  ('017808d29fd1f942d97e50184dfb4c13', '8daaa9e99d60fbba579cc1c3e3bfae01', 5, None, None, '2018-03-02 00:00:00', '2018-03-05 01:43:30'),
#  ('017808d29fd1f942d97e50184dfb4c13', 'b1461c8882153b5fe68307c46a506e39', 5, None, None, '2018-03-02 00:00:00', '2018-03-05 01:43:30'),
#  ('0254bd905dc677a6078990aad3331a36', '331b367bdd766f3d1cf518777317b5d9', 1, None, 'O pedido consta de 2 produtos e até agora recebi apenas 1 produto, e o que me preocupa é que o status aparece como entregue.\nSolicito providências', '2017-09-09 00:00:00', '2017-09-13 09:52:44'),
#  ('0254bd905dc677a6078990aad3331a36', '5bf226cf882c5bf4247f89a97c86f273', 1, None, 'O pedido consta de 2 produtos e até agora recebi apenas 1 produto, e o que me preocupa é que o status aparece como entregue.\nSolicito providências', '2017-09-09 00:00:00', '2017-09-13 09:52:44'),
#  ('0288d42bef3dfe36930740c9588a570f', '33d8795f04dd631f3480d7aaf90da3dc', 3, None, None, '2017-07-29 00:00:00', '2017-07-31 17:11:04'),
#  ('0288d42bef3dfe36930740c9588a570f', 'f889a5a0b44adc29c5465b99395ac3c1', 3, None, None, '2017-07-29 00:00:00', '2017-07-31 17:11:04'),
#  ('02aa7f5f75e964e3c7efa59a1f515281', 'db92613c074f00e53066388d48ad7512', 3, None, None, '2017-07-27 00:00:00', '2017-07-29 15:09:50'),
#  ('02aa7f5f75e964e3c7efa59a1f515281', 'd8e17d5f7dacf0970d316e7c03e741e8', 3, None, None, '2017-07-27 00:00:00', '2017-07-29 15:09:50'),
#  ('034528cb00b6bc981847acafbdf2ae0b', 'e1e8e3bca903de27e9a1c72b5a5795e0', 1, None, None, '2017-05-14 00:00:00', '2017-05-15 02:17:38'),
#  ('034528cb00b6bc981847acafbdf2ae0b', '3d3742a96f24a8fe4e2e57628807e476', 1, None, None, '2017-05-14 00:00:00', '2017-05-15 02:17:38'),
#  ('03a6a25db577d0689440933055111897', '2acfdc5131ff2cf4433e668454c9784c', 5, None, 'Muito Bom! Gostei Bastante! Tecido Ótimo! Atendeu Minhas Espectativas! 👏👏👏 Super Recomendo! 👍', '2017-12-15 00:00:00', '2017-12-16 01:32:18'),
#  ('03a6a25db577d0689440933055111897', '3fde8b7313af6b37b84b5c7594d7add0', 5, None, 'Muito Bom! Gostei Bastante! Tecido Ótimo! Atendeu Minhas Espectativas! 👏👏👏 Super Recomendo! 👍', '2017-12-15 00:00:00', '2017-12-16 01:32:18'),
#  ('0467560f511c516ddaa54a60edb0c291', '55b2e390d5d80ada31ad1b795ebeb087', 5, None, None, '2017-02-09 00:00:00', '2017-02-14 15:58:44'),
#  ('0467560f511c516ddaa54a60edb0c291', '0c995611a99f81268d859184a416f1db', 5, None, None, '2017-02-09 00:00:00', '2017-02-14 15:58:44'),
#  ('047fd109ced39e02296f6aeb74f6a6f1', '236e6ec6171c1870d4bcf4ccfad87f49', 4, None, None, '2018-07-31 00:00:00', '2018-08-02 15:11:49'),
#  ('047fd109ced39e02296f6aeb74f6a6f1', 'a89abace0dcc01eeb267a9660b5ac126', 4, None, None, '2018-07-31 00:00:00', '2018-08-02 15:11:49'),
#  ('0498e9722f8757426c3c3ee0b91e666d', '041aa5c38550649d5b51f38ba03a29a4', 4, None, 'Chego certo adoro comprar na lannister.com.br\nQto ao produto ainda não usei.', '2018-03-03 00:00:00', '2018-03-06 01:00:33'),
#  ('0498e9722f8757426c3c3ee0b91e666d', 'f318811b0fd898d1edf78d6841470be2', 4, None, 'Chego certo adoro comprar na lannister.com.br\nQto ao produto ainda não usei.', '2018-03-03 00:00:00', '2018-03-06 01:00:33'),
#  ('0501aab2f381486c36bf0f071442c0c2', 'd75cb3755738c4ae466303358f97bc55', 1, None, 'Espero obter uma resposta para minha encomenda. Comprei 3 controles remotos para ar condicionado e apenas recebi 1 controle Komeco e dos 2 controles Elgin pedidos e pago só foi entregue 1 controle Elg', '2018-02-09 00:00:00', '2018-02-10 23:55:18'),
#  ('0501aab2f381486c36bf0f071442c0c2', '0068c109948b9a1dfb8530d1978acef3', 1, None, 'Espero obter uma resposta para minha encomenda. Comprei 3 controles remotos para ar condicionado e apenas recebi 1 controle Komeco e dos 2 controles Elgin pedidos e pago só foi entregue 1 controle Elg', '2018-02-09 00:00:00', '2018-02-10 23:55:18'),
#  ('0546d398a833d4c33dec480bedeecfbd', 'e72a8568c8622825a95439791f668e85', 5, None, None, '2017-10-05 00:00:00', '2017-10-24 16:16:33'),
#  ('0546d398a833d4c33dec480bedeecfbd', '879d57dc015759bf30e71a20b5ae0652', 5, None, None, '2017-10-05 00:00:00', '2017-10-24 16:16:33'),
#  ('0655af56f10bc3ef8e3810610828f294', 'd9e44c3fd2ce16086619f299e92e12d8', 5, None, 'Muito rápido a entrega', '2017-05-18 00:00:00', '2017-05-19 19:15:22'),
#  ('0655af56f10bc3ef8e3810610828f294', '84f5e6c0a0e3155e38c00f434ba90ce8', 5, None, 'Muito rápido a entrega', '2017-05-18 00:00:00', '2017-05-19 19:15:22'),
#  ('06e327fb381850fdd69fba40ad61b2f2', '46d2741b78a72c2f07bf0f3c34c4ceab', 2, None, None, '2017-06-02 00:00:00', '2017-06-05 14:08:36'),
#  ('06e327fb381850fdd69fba40ad61b2f2', 'ce0102221c8d12a97979c74d09cca282', 2, None, None, '2017-06-02 00:00:00', '2017-06-05 14:08:36'),
#  ('0837bc8fa2cb75353513858b3bb5be1d', 'd36b13fdc087b62c490a9db5c0e0a913', 5, None, None, '2017-10-18 00:00:00', '2017-10-20 09:38:18'),
#  ('0837bc8fa2cb75353513858b3bb5be1d', '3ab974ac744bd19a111d5e19f0a90649', 5, None, None, '2017-10-18 00:00:00', '2017-10-20 09:38:18'),
#  ('08528f70f579f0c830189efc523d2182', '53c71d3953507c6239ff73917ed358c9', 1, 'Produto errado', 'Entrega do produto diferente do solicitado\nAguardo orientação para a troca', '2018-08-03 00:00:00', '2018-08-06 00:09:52'),
#  ('08528f70f579f0c830189efc523d2182', '03310aa823a66056268a3bab36e827fb', 1, 'Produto errado', 'Entrega do produto diferente do solicitado\nAguardo orientação para a troca', '2018-08-03 00:00:00', '2018-08-06 00:09:52'),
#  ('08528f70f579f0c830189efc523d2182', '7813842ae95e8c497fc0233232ae815a', 1, 'Produto errado', 'Entrega do produto diferente do solicitado\nAguardo orientação para a troca', '2018-08-03 00:00:00', '2018-08-06 00:09:52'),
#  ('08531aa0b3844944e7aeef53530f8598', 'b1fdceb28f70830d69114860d8b1175a', 5, None, 'Tudo ok!! Produto entregue no prazo!!', '2017-08-02 00:00:00', '2017-08-02 23:40:50'),
#  ('08531aa0b3844944e7aeef53530f8598', 'a65820c7e4307f72117e77fce6be1074', 5, None, 'Tudo ok!! Produto entregue no prazo!!', '2017-08-02 00:00:00', '2017-08-02 23:40:50'),
#  ('08a86da22498172adb6cefaa99fdfaf7', '3c0f91a7a3493bb46260f52f2e6ab61a', 1, None, 'Prazo de entrega gigante e mesmo assim conseguiram atrasar a entrega.', '2018-03-28 00:00:00', '2018-03-28 09:54:06'),
#  ('08a86da22498172adb6cefaa99fdfaf7', 'c775dea8bfab02a285d4d3b9f247808d', 1, None, 'Prazo de entrega gigante e mesmo assim conseguiram atrasar a entrega.', '2018-03-28 00:00:00', '2018-03-28 09:54:06'),
#  ('090aa2980b0aea78cd1ae73447d7d55b', 'b9a528ec4ad891d009b3dc50588218f1', 4, None, None, '2018-05-10 00:00:00', '2018-05-11 10:52:52'),
#  ('090aa2980b0aea78cd1ae73447d7d55b', '66f943fd426ac8716ef6b6b97ace8bd8', 4, None, None, '2018-05-10 00:00:00', '2018-05-11 10:52:52'),
#  ('09534ea272eea99209ff37c5c348ceb1', '4acfa8594925fd16246cef2ad2e4fb4a', 5, None, None, '2018-01-23 00:00:00', '2018-01-24 00:47:07'),
#  ('09534ea272eea99209ff37c5c348ceb1', '4cf18bf9d25331902ba212fa69a7a01d', 5, None, None, '2018-01-23 00:00:00', '2018-01-24 00:47:07'),
#  ('09b871b3f4f85d3595cb37054a9105f1', '2d4f4cfa89af135842ed4770de178752', 3, None, None, '2017-08-19 00:00:00', '2017-08-24 16:04:24'),
#  ('09b871b3f4f85d3595cb37054a9105f1', 'bcf4f139b50c6689378fac7fe255a186', 3, None, None, '2017-08-19 00:00:00', '2017-08-24 16:04:24'),
#  ('0a2d1206f8b2473cd3ddf69b51bca98a', '7ceb3c8bbf48eaa776064d56012afbc1', 5, None, None, '2018-03-14 00:00:00', '2018-03-16 09:05:13'),
#  ('0a2d1206f8b2473cd3ddf69b51bca98a', '8c389c12aa23b689926d20a01729206d', 5, None, None, '2018-03-14 00:00:00', '2018-03-16 09:05:13'),
#  ('0a3b875d00f437f25215e0ac942efca2', '110f23195a2ddb2ccaad30b37bfacbbf', 5, None, None, '2017-12-28 00:00:00', '2017-12-29 06:06:50'),
#  ('0a3b875d00f437f25215e0ac942efca2', '8d42bc7cf9914679406f48db0e05e571', 5, None, None, '2017-12-28 00:00:00', '2017-12-29 06:06:50'),
#  ('0a3caf6324edd5158b342ee5a0886271', '6618ba440a8c54ff6e7dfcf5c7300265', 5, None, None, '2017-06-06 00:00:00', '2017-06-07 02:54:31'),
#  ('0a3caf6324edd5158b342ee5a0886271', 'cfea19cacc7328f2fccb914fb0fd5fe2', 5, None, None, '2017-06-06 00:00:00', '2017-06-07 02:54:31'),
#  ('0a6ec47c5d78509672e16b95efcff53b', '5244b9f2f8bc60aa503830f2847082f1', 5, None, None, '2017-05-08 00:00:00', '2017-05-08 17:57:57'),
#  ('0a6ec47c5d78509672e16b95efcff53b', 'e504f586e9ffc862cad95482af740af4', 5, None, None, '2017-05-08 00:00:00', '2017-05-08 17:57:57'),
#  ('0ad57b9e68d4d34814464772b6de54fe', '75213e459cfe44a61c496c864e0a8c63', 1, None, None, '2017-12-17 00:00:00', '2017-12-18 04:22:36'),
#  ('0ad57b9e68d4d34814464772b6de54fe', 'd22f0b06e1519065d7eddb2ba6b79b63', 1, None, None, '2017-12-17 00:00:00', '2017-12-18 04:22:36'),
#  ('0ad87184dc47c36db717b98e8baca9cc', 'c32fc9ccb03292ac2e7a2c2f027394ff', 4, 'BOM', 'BOA ENTREGA', '2018-07-31 00:00:00', '2018-07-31 16:47:05'),
#  ('0ad87184dc47c36db717b98e8baca9cc', 'b4c317bb5f8fb237f37171f190e8d332', 4, 'BOM', 'BOA ENTREGA', '2018-07-31 00:00:00', '2018-07-31 16:47:05'),
#  ('0b51553f3cd2e9606b9c0f25667dc5bb', 'ac08c0b67890296c7c7c10f34b81eea4', 5, None, None, '2018-03-15 00:00:00', '2018-03-15 11:00:21'),
#  ('0b51553f3cd2e9606b9c0f25667dc5bb', '095e9e0811476409362d72fa70d73a6c', 5, None, None, '2018-03-15 00:00:00', '2018-03-15 11:00:21'),
#  ('0b9af3c12843b743f612ca8abbc33e83', '61845fa79785f181ff99f39e39f40740', 5, None, None, '2017-11-02 00:00:00', '2017-11-02 22:36:20'),
#  ('0b9af3c12843b743f612ca8abbc33e83', '37732eb932f8b2b2b3d7cef77833eec1', 5, None, None, '2017-11-02 00:00:00', '2017-11-02 22:36:20'),
#  ('0bb958acd9e40d9348635c75013f7b19', '4f9f24f1dd52ecdf0684a63eaf36c51b', 4, None, None, '2017-04-01 00:00:00', '2017-04-04 10:21:31'),
#  ('0bb958acd9e40d9348635c75013f7b19', '473f6fac1db5ed68ee9f1ad1e7c14aae', 4, None, None, '2017-04-01 00:00:00', '2017-04-04 10:21:31'),
#  ('0c0b58839bdc7b7d49396ddf94a3dbf7', '892e04325197686b3f5a32eb5fb38177', 5, None, None, '2018-03-01 00:00:00', '2018-03-02 11:00:31'),
#  ('0c0b58839bdc7b7d49396ddf94a3dbf7', '3c557fef5b5d9315a99f7442ef013a8e', 5, None, None, '2018-03-01 00:00:00', '2018-03-02 11:00:31'),
#  ('0c1f10775ef729e60b56d9c6dcc47736', 'd98a4e525a6240595557fbf149ff82da', 5, None, None, '2018-02-21 00:00:00', '2018-02-22 03:03:18'),
#  ('0c1f10775ef729e60b56d9c6dcc47736', 'cf223cd5f53b6a5986f1ef788d3e9e83', 5, None, None, '2018-02-21 00:00:00', '2018-02-22 03:03:18'),
#  ('0c2915e69ee09c18b9c15b8035bdc5ff', '7433b1786e1af2042c2c4c76d3e4b750', 4, None, 'Manta bonita e grande, exatamente como estava no site. Gostei!!!', '2017-06-20 00:00:00', '2017-06-21 00:14:13'),
#  ('0c2915e69ee09c18b9c15b8035bdc5ff', 'a4b276bd4a9eba543ec90cdf29a67308', 4, None, 'Manta bonita e grande, exatamente como estava no site. Gostei!!!', '2017-06-20 00:00:00', '2017-06-21 00:14:13'),
#  ('0c76e7a547a531e7bf9f0b99cba071c1', '3525e0e57f9d276d522d570bd46cb39c', 5, None, None, '2017-08-31 00:00:00', '2017-09-05 15:27:17'),
#  ('0c76e7a547a531e7bf9f0b99cba071c1', '16cc0fe71527d13426bdbe29205b2053', 5, None, None, '2017-08-31 00:00:00', '2017-09-05 15:27:17'),
#  ('0c76e7a547a531e7bf9f0b99cba071c1', '98c977c116f7779360e9fecffd3860b6', 5, None, None, '2017-08-31 00:00:00', '2017-09-05 15:27:17'),
#  ('0c8e7347f1cdd2aede37371543e3d163', '81c2d284094f3b39baddefb519a30149', 3, None, 'UM DOS PRODUTOS (ENTREGA02) COMPRADOS NESTE PEDIDO NAO RECEBI AINDA E OUTRO (ENTREGA01) RECEBI EMAIL QUE ESTA COM DIFICULDADES NA ENTREGA E NÃO TIVE MAIS NOTICIAS', '2018-03-21 00:00:00', '2018-03-22 01:32:08'),
#  ('0c8e7347f1cdd2aede37371543e3d163', '02355020fd0a40a0d56df9f6ff060413', 3, None, 'UM DOS PRODUTOS (ENTREGA02) COMPRADOS NESTE PEDIDO NAO RECEBI AINDA E OUTRO (ENTREGA01) RECEBI EMAIL QUE ESTA COM DIFICULDADES NA ENTREGA E NÃO TIVE MAIS NOTICIAS', '2018-03-21 00:00:00', '2018-03-22 01:32:08'),
#  ('0e18d426420da859dfd6fb4beaba9efe', '6561717586fb2d3ae85fce2964f600e1', 5, None, '100% ótimo!', '2018-03-08 00:00:00', '2018-03-08 22:12:19'),
#  ('0e18d426420da859dfd6fb4beaba9efe', '30dbdad7616e8b72efea1c866a43f1da', 5, None, '100% ótimo!', '2018-03-08 00:00:00', '2018-03-08 22:12:19'),
#  ('0e249472bec47b0c4b88a8e8bfa8d241', '8b1a9c54d1ba09cc40591511d388d286', 1, None, 'Deveriam contratar transportadora e não correio até o momento não recebi minha encomenda', '2017-10-01 00:00:00', '2017-10-01 04:07:46'),
#  ('0e249472bec47b0c4b88a8e8bfa8d241', '7b994fc7c7528d2098eebcb19d18ce7e', 1, None, 'Deveriam contratar transportadora e não correio até o momento não recebi minha encomenda', '2017-10-01 00:00:00', '2017-10-01 04:07:46'),
#  ('0ec0f24aa34a9b25fb0f7b32034965ce', '3c6566c0b8aa1eb2382e08cc0ae4bab4', 5, None, 'Entrega muito rápida.', '2017-12-28 00:00:00', '2017-12-31 03:45:51'),
#  ('0ec0f24aa34a9b25fb0f7b32034965ce', 'b2072c2ef2726db9126e404a9e486365', 5, None, 'Entrega muito rápida.', '2017-12-28 00:00:00', '2017-12-31 03:45:51'),
#  ('0efebc2c5add22c5b45867716919dcdd', '9b24c8496d87684865617cdb3eff7065', 4, None, 'faltou entregar 1 cortina, mandei msg ontem mesmo, o porteiro recebeu pq eu não estava em casa, a nota consta 3 cortinas mas só foram entregues 2, verificar por favor pq deve ter sobrado 1 no carro', '2017-10-15 01:00:00', '2017-10-15 15:30:44'),
#  ('0efebc2c5add22c5b45867716919dcdd', 'afc5e76e5cc169a08cec884d98173efb', 4, None, 'faltou entregar 1 cortina, mandei msg ontem mesmo, o porteiro recebeu pq eu não estava em casa, a nota consta 3 cortinas mas só foram entregues 2, verificar por favor pq deve ter sobrado 1 no carro', '2017-10-15 01:00:00', '2017-10-15 15:30:44'),
#  ('0f45a7a6cab5ac1c9cc25ce1eb2357d2', '43c564b825003473af9a68138631d388', 5, None, None, '2017-08-13 00:00:00', '2017-08-13 23:34:28'),
#  ('0f45a7a6cab5ac1c9cc25ce1eb2357d2', 'b61a2f7167a516d76088020bc63b4f7b', 5, None, None, '2017-08-13 00:00:00', '2017-08-13 23:34:28'),
#  ('0ffae99e57188428340c206afb957a1c', '8b426ff8aa1c03dc173f1270133b408e', 1, None, 'Marca como entregue 2 produtos....mas na realidade recebi apenas 1....Falta tapete de borboleta', '2017-08-23 00:00:00', '2017-08-26 05:13:02'),
#  ('0ffae99e57188428340c206afb957a1c', '0a0090ae69392fa38ee742006f8c0a90', 1, None, 'Marca como entregue 2 produtos....mas na realidade recebi apenas 1....Falta tapete de borboleta', '2017-08-23 00:00:00', '2017-08-26 05:13:02'),
#  ('10398bad17ab17c451c39a0b2c47464c', '36783db8698edf3ba7585d93b5a1c4bf', 5, None, None, '2018-04-04 00:00:00', '2018-04-09 00:00:43'),
#  ('10398bad17ab17c451c39a0b2c47464c', '412e4fb4c148a6d31f905c16481d75e6', 5, None, None, '2018-04-04 00:00:00', '2018-04-09 00:00:43'),
#  ('105facb42b5b9147996f0b1b6fbf7b80', '04c3bddd55df58e83123e3b174855489', 1, None, 'Holá!\nNão recebi o produto é nem um telefonema referente ao que comprei.', '2018-02-24 00:00:00', '2018-02-27 00:13:54'),
#  ('105facb42b5b9147996f0b1b6fbf7b80', '714fb133a6730ab81fa1d3c1b2007291', 1, None, 'Holá!\nNão recebi o produto é nem um telefonema referente ao que comprei.', '2018-02-24 00:00:00', '2018-02-27 00:13:54'),
#  ('10bca0461c36ef14701fa28971d0cdb5', '46984ee8227e1926e055327b55ad576c', 1, None, 'Produto com defeito, solicitei a devolução do mesmo.', '2018-01-04 00:00:00', '2018-01-04 20:13:59'),
#  ('10bca0461c36ef14701fa28971d0cdb5', 'fdf7396bbd1e126f45ba0fc3896360a7', 1, None, 'Produto com defeito, solicitei a devolução do mesmo.', '2018-01-04 00:00:00', '2018-01-04 20:13:59'),
#  ('11912dbae5f169782098a20fc51c0b33', '440fd902b617080eeb9463a65ffae07a', 1, None, 'Comprei o produto e quando chegou veio na cor rosa, ao invez da cor vermelha como na foto... Pedi o cancelamento do produto ja tem mais de 1 mes e ate agora nada do reembolso... muito demorado', '2018-02-06 00:00:00', '2018-03-05 15:21:00'),
#  ('11912dbae5f169782098a20fc51c0b33', '4b5893f13b0e06d63d6a27fd04544deb', 1, None, 'Comprei o produto e quando chegou veio na cor rosa, ao invez da cor vermelha como na foto... Pedi o cancelamento do produto ja tem mais de 1 mes e ate agora nada do reembolso... muito demorado', '2018-02-06 00:00:00', '2018-03-05 15:21:00'),
#  ('11c94569cabc7d493a0aa1c5cd1dbfb4', 'a5a322511ad2f5a5296e865cd5c23abe', 5, None, 'Ótimo produto. Custo e benefício.', '2017-10-12 00:00:00', '2017-10-12 16:47:14'),
#  ('11c94569cabc7d493a0aa1c5cd1dbfb4', '097abce97e431993434adabc1aaec4e4', 5, None, 'Ótimo produto. Custo e benefício.', '2017-10-12 00:00:00', '2017-10-12 16:47:14'),
#  ('12476f0c366e9de86c46fbced6372d92', '18fdcbdf78e62bac03cf30b6b9398087', 5, None, None, '2017-06-06 00:00:00', '2017-06-11 03:58:26'),
#  ('12476f0c366e9de86c46fbced6372d92', 'f6a3c840a4982c53155907a2fb3b8318', 5, None, None, '2017-06-06 00:00:00', '2017-06-11 03:58:26'),
#  ('1258a603cc9e4897f7955ab218c83b8c', '3d0acef161147c90c2fd5e7cd8e199e1', 3, None, None, '2018-02-03 00:00:00', '2018-02-03 23:43:14'),
#  ('1258a603cc9e4897f7955ab218c83b8c', '4a4c3e1ff92b16c0ecf770b504693a88', 3, None, None, '2018-02-03 00:00:00', '2018-02-03 23:43:14'),
#  ('12f2fd663de5670387805fd70ece2e21', '77ef3216467887c78ddec18de86a58b9', 5, None, None, '2018-07-26 00:00:00', '2018-07-29 17:02:57'),
#  ('12f2fd663de5670387805fd70ece2e21', 'b76e1e63723d846f3382683973908122', 5, None, None, '2018-07-26 00:00:00', '2018-07-29 17:02:57'),
#  ('135df63f4871bf893d89ca67df0f921c', '0943d27820129d9446a32ca20cf9bee1', 3, None, None, '2017-02-16 00:00:00', '2017-02-17 08:53:37'),
#  ('135df63f4871bf893d89ca67df0f921c', '661e075fa45fa4a73a79dd6972bce18b', 3, None, None, '2017-02-16 00:00:00', '2017-02-17 08:53:37'),
#  ('13b2872ada20991c4f52ccb141cb1705', '32b1d3f7e7a0149ea3c10792131839d5', 5, 'nota 10', None, '2018-07-26 00:00:00', '2018-07-27 11:11:08'),
#  ('13b2872ada20991c4f52ccb141cb1705', 'a0ac0049119c70e88509f0c8e30564e8', 5, 'nota 10', None, '2018-07-26 00:00:00', '2018-07-27 11:11:08'),
#  ('13cc14a5f7a442a1ecce8f32b463e242', 'd3feb75cb4e8d372a35e074fc1175bcd', 5, None, 'Tudo certo com a entrega. \nTudo certo com o produto, super recomendo.', '2017-09-14 00:00:00', '2017-09-15 09:41:57'),
#  ('13cc14a5f7a442a1ecce8f32b463e242', '396edbf3fd93df6ebe7bb415f5af60c9', 5, None, 'Tudo certo com a entrega. \nTudo certo com o produto, super recomendo.', '2017-09-14 00:00:00', '2017-09-15 09:41:57'),
#  ('13d45c97ae78e0ef1361835b8944b7b0', 'ad22d501d12b05b17afda08f06ce8bfd', 5, None, None, '2018-04-03 00:00:00', '2018-04-06 09:42:34'),
#  ('13d45c97ae78e0ef1361835b8944b7b0', '752df1d3d4248c9dc8cca21cd6b42675', 5, None, None, '2018-04-03 00:00:00', '2018-04-06 09:42:34'),
#  ('1439640ba4905dc2f98188cad2a77154', '824fa8179b9911d58831e0b09eedde13', 5, None, 'Estante chegou muito bem embalada e no prazo. Mercadoria conforme anuncio. \nGostei', '2017-07-27 00:00:00', '2017-07-31 03:27:15'),
#  ('1439640ba4905dc2f98188cad2a77154', '6066fbcebeaf378770ad9fbe8e30d1f0', 5, None, 'Estante chegou muito bem embalada e no prazo. Mercadoria conforme anuncio. \nGostei', '2017-07-27 00:00:00', '2017-07-31 03:27:15'),
#  ('1442a23fe4555fda0f7c7eb7ba5ae3b1', 'f50654324d7bc3b79e01a02199fe1585', 5, None, None, '2017-12-28 00:00:00', '2017-12-28 18:36:07'),
#  ('1442a23fe4555fda0f7c7eb7ba5ae3b1', 'bb3b63f8a09bf476fd524c44fb767a31', 5, None, None, '2017-12-28 00:00:00', '2017-12-28 18:36:07'),
#  ('15c9136f43468a8428316d9871eaf14d', '3ea8ef64da06a959e384edb7cb824c02', 4, None, None, '2017-06-06 00:00:00', '2017-06-06 23:02:21'),
#  ('15c9136f43468a8428316d9871eaf14d', '26a887fe1515ba3501b5154e443ca899', 4, None, None, '2017-06-06 00:00:00', '2017-06-06 23:02:21'),
#  ('15daa9db89623052d7b25d96ed14686d', '62eb76321ff33a367a805bc9d0701dda', 3, None, 'Não credito todo o erro ao fornecedor.\nA baratheon também tem responsabilidade. Comprei na baratheon. Obrigada.', '2018-01-04 00:00:00', '2018-01-04 15:09:50'),
#  ('15daa9db89623052d7b25d96ed14686d', 'bf9a3a8d9db6be5e4dfcfe2f071ef405', 3, None, 'Não credito todo o erro ao fornecedor.\nA baratheon também tem responsabilidade. Comprei na baratheon. Obrigada.', '2018-01-04 00:00:00', '2018-01-04 15:09:50'),
#  ('161160f7f3602ec0de9cd583b62b3b15', 'd898dd2a514f62601dc99b7858023038', 5, None, 'só recebi a navalha tá faltando a máquina de cortar cabelo e o kit tesoura', '2017-11-02 00:00:00', '2017-11-03 00:23:24'),
#  ('161160f7f3602ec0de9cd583b62b3b15', '155809b08fd56a13a541ff3ea4e9db2a', 5, None, 'só recebi a navalha tá faltando a máquina de cortar cabelo e o kit tesoura', '2017-11-02 00:00:00', '2017-11-03 00:23:24'),
#  ('167b40b617e650de2c473d70baae2e65', 'b37a7e90838d63c38152d2f8c432a726', 5, None, 'entrega no prazo correto produto em otima qualidade super satisfeita com a minha compra\nmuito feliz pelo o produto adquerido tanto na entrega como na qualidade do material recebido', '2018-03-16 00:00:00', '2018-03-19 16:37:49'),
#  ('167b40b617e650de2c473d70baae2e65', 'cb5b7fb63c0add7098c025cb737df02e', 5, None, 'entrega no prazo correto produto em otima qualidade super satisfeita com a minha compra\nmuito feliz pelo o produto adquerido tanto na entrega como na qualidade do material recebido', '2018-03-16 00:00:00', '2018-03-19 16:37:49'),
#  ('168b708c0e1d90f89c9737b1160121d6', '92ef3140d9d92187a04b1bd643f32dc1', 5, None, None, '2017-09-09 00:00:00', '2017-09-12 12:57:29'),
#  ('168b708c0e1d90f89c9737b1160121d6', 'fbb3296cbee389d9961a820220eb62a3', 5, None, None, '2017-09-09 00:00:00', '2017-09-12 12:57:29'),
#  ('1708c3eec64152cb52fe56bb3abcf257', '5dc05f32211efb743fde17f226adfb6b', 4, None, 'Produto correspondeu as discrições', '2017-08-30 00:00:00', '2017-08-30 15:59:46'),
#  ('1708c3eec64152cb52fe56bb3abcf257', '451ef728c85c9cb2765159e30f4fa021', 4, None, 'Produto correspondeu as discrições', '2017-08-30 00:00:00', '2017-08-30 15:59:46'),
#  ('17592266cd3216a98665ebfd6365843a', '3ca618a967a369a20ac5f2c4e00e151a', 1, None, 'Não recebi o produto', '2018-01-06 00:00:00', '2018-01-10 02:49:16'),
#  ('17592266cd3216a98665ebfd6365843a', 'c229c6a2f0ecb33d8e2779ebddec3a1f', 1, None, 'Não recebi o produto', '2018-01-06 00:00:00', '2018-01-10 02:49:16'),
#  ('176a37898b45f9db0b8de7641973bf53', '5b0cbe028ba75896dcef147e3cfaae1b', 5, None, None, '2017-08-25 00:00:00', '2017-08-28 12:23:39'),
#  ('176a37898b45f9db0b8de7641973bf53', '500aced6001e75a49db10f0ae54f94f1', 5, None, None, '2017-08-25 00:00:00', '2017-08-28 12:23:39'),
#  ('1775bd097716d67420d128df008252eb', '04a2ba381317648726f46210a46ece95', 5, None, None, '2018-08-04 00:00:00', '2018-08-04 21:58:02'),
#  ('1775bd097716d67420d128df008252eb', '0b3ca8c9e3b3199306adb467fcd0e982', 5, None, None, '2018-08-04 00:00:00', '2018-08-04 21:58:02'),
#  ('17939259ccc419f355fb4a148151fb00', '7720e8564b9fee98c22438680fa85cfb', 4, None, None, '2017-05-24 00:00:00', '2017-05-26 18:54:13'),
#  ('17939259ccc419f355fb4a148151fb00', '00d94e8901b75ee0d6ef1f87f947b666', 4, None, None, '2017-05-24 00:00:00', '2017-05-26 18:54:13'),
#  ('18071cb247f057c348988037fa94a0cd', '27667a063cb59b5d987a5a71c192cce5', 1, 'Anúncio ambíguo dá errado', 'Lentes de contato são positivas, para hipermetropia, ou negativas, para miopia. Tenho hipermetropia, preciso de lentes positivas.\nForam entregues lentes negativas. Ninguém me atende para resolver.', '2018-08-02 00:00:00', '2018-08-03 01:34:51'),
#  ('18071cb247f057c348988037fa94a0cd', '4c8b9947280829d0a8b7e81cc249b875', 1, 'Anúncio ambíguo dá errado', 'Lentes de contato são positivas, para hipermetropia, ou negativas, para miopia. Tenho hipermetropia, preciso de lentes positivas.\nForam entregues lentes negativas. Ninguém me atende para resolver.', '2018-08-02 00:00:00', '2018-08-03 01:34:51'),
#  ('183808dc516fab3df74b087310299cf0', '29210b1d48462ce1f12d87ed7ccd6397', 5, None, 'Ainda não usei o produto, mas em relação à entrega, chegou muito antes do esperado.', '2018-02-07 00:00:00', '2018-02-08 01:17:50'),
#  ('183808dc516fab3df74b087310299cf0', '374a125372cffb30e8e2df55f8448da4', 5, None, 'Ainda não usei o produto, mas em relação à entrega, chegou muito antes do esperado.', '2018-02-07 00:00:00', '2018-02-08 01:17:50'),
#  ('19194f53840fc6c2857dd8809972a209', 'ca263afd88a8a1200605adbd4b63cd7d', 4, None, None, '2018-01-23 00:00:00', '2018-01-24 12:43:58'),
#  ('19194f53840fc6c2857dd8809972a209', '82fd1196a459f594fb1d66e667fc74c4', 4, None, None, '2018-01-23 00:00:00', '2018-01-24 12:43:58'),
#  ('193d73d33b656807084215db91b23b8c', '42ae1967f68c90bb325783ac55d761ce', 3, None, None, '2017-07-19 00:00:00', '2017-07-19 12:22:10'),
#  ('193d73d33b656807084215db91b23b8c', 'd78c16f09da03410837a551a09a4bf64', 3, None, None, '2017-07-19 00:00:00', '2017-07-19 12:22:10'),
#  ('1961cafe1d1cbd4cc701c2f0160467ff', '2699d27682691fa4f6be5cfde364a833', 5, None, 'Confiável e super indico', '2017-06-16 00:00:00', '2017-06-18 17:47:59'),
#  ('1961cafe1d1cbd4cc701c2f0160467ff', '497f97bb280fe07465c3833fdfc04736', 5, None, 'Confiável e super indico', '2017-06-16 00:00:00', '2017-06-18 17:47:59'),
#  ('19d60869413aa63834affc9ecc9d9f90', 'a685d016c8a26f71a0bb67821070e398', 1, None, 'Não recebi', '2017-04-02 00:00:00', '2017-04-02 10:58:38'),
#  ('19d60869413aa63834affc9ecc9d9f90', '7f13a20e25350f4a55fb2a7c9a2e8d88', 1, None, 'Não recebi', '2017-04-02 00:00:00', '2017-04-02 10:58:38'),
#  ('1a6be4c794d5e3da242a364f6a98163f', 'ff536d93ae4214b4d51c2894ccfc569f', 3, None, 'Chigling', '2017-12-28 00:00:00', '2017-12-28 22:54:59'),
#  ('1a6be4c794d5e3da242a364f6a98163f', '316119df99801d35bea84dbe48f4765e', 3, None, 'Chigling', '2017-12-28 00:00:00', '2017-12-28 22:54:59'),
#  ('1b5dc3da2372e9bb5518cd37cd9a9354', '5ddea4bc0239f874cd7d6fd398d6045a', 2, None, 'Demorou para entregar', '2017-06-22 00:00:00', '2017-06-24 23:04:49'),
#  ('1b5dc3da2372e9bb5518cd37cd9a9354', '2af768daf2646f316e9457e1f10b2428', 2, None, 'Demorou para entregar', '2017-06-22 00:00:00', '2017-06-24 23:04:49'),
#  ('1b8df55d40e129a4003858afb671129c', 'b12e5d725658a4566286153c51727af2', 4, None, None, '2017-05-24 00:00:00', '2017-05-27 11:14:56'),
#  ('1b8df55d40e129a4003858afb671129c', 'a979479c1af57af858b45dfd2d67ee04', 4, None, None, '2017-05-24 00:00:00', '2017-05-27 11:14:56'),
#  ('1bda8c20e199f7c2e9a342600031518b', 'a30cadd1758dccbec1ba83a6d672fd1c', 5, None, None, '2018-08-07 00:00:00', '2018-08-07 23:05:28'),
#  ('1bda8c20e199f7c2e9a342600031518b', 'ea8efd0043199fe88f31e1fea2e840f6', 5, None, None, '2018-08-07 00:00:00', '2018-08-07 23:05:28'),
#  ('1c0c84f0e3132c3af0a17f0aa4987879', '60b3fa9424e97cd3b6b95ca799d511c6', 1, None, 'Muito ruim a qualidade, as bordas do desenho veio com aspecto de queimado, não consigo tirar a pelicula da frente do espelho pra ver se afetou o mesmo... sem adesivo pra fixar.', '2017-08-23 00:00:00', '2017-08-27 23:36:45'),
#  ('1c0c84f0e3132c3af0a17f0aa4987879', '24cdfd401a113857553214161447483a', 1, None, 'Muito ruim a qualidade, as bordas do desenho veio com aspecto de queimado, não consigo tirar a pelicula da frente do espelho pra ver se afetou o mesmo... sem adesivo pra fixar.', '2017-08-23 00:00:00', '2017-08-27 23:36:45'),
#  ('1c7a92108afc9782646581517fbb2808', '814b1f69511cfbaa3b54bf7701c7a475', 4, None, None, '2017-06-20 00:00:00', '2017-06-21 03:23:04'),
#  ('1c7a92108afc9782646581517fbb2808', '78f60565caf7dc3b87f6e1e9b03b691d', 4, None, None, '2017-06-20 00:00:00', '2017-06-21 03:23:04'),
#  ('1c7b8b15de9a2eff8caac4ece3fc0f49', 'a47bf2de96db0109440cc21208edcc4f', 5, None, None, '2018-03-15 00:00:00', '2018-03-16 00:49:55'),
#  ('1c7b8b15de9a2eff8caac4ece3fc0f49', '7da5789072aa14cff7a42564283c6254', 5, None, None, '2018-03-15 00:00:00', '2018-03-16 00:49:55'),
#  ('1c7e1a24358cea9db1eecc6987843a28', 'a79c4dca347540e1263b2b750b92d8ab', 5, None, None, '2017-09-16 00:00:00', '2017-09-17 18:00:10'),
#  ('1c7e1a24358cea9db1eecc6987843a28', 'f0dd9af88d8ef5a8e4670fbbedaf19c4', 5, None, None, '2017-09-16 00:00:00', '2017-09-17 18:00:10'),
#  ('1c9023a88f4effba4abbf114c58bedba', 'b7293e3014a7261f0d26d28a1e927864', 4, None, None, '2017-11-09 00:00:00', '2017-11-13 23:23:05'),
#  ('1c9023a88f4effba4abbf114c58bedba', '9d6e7e70e068602fa740fc3163cefd3b', 4, None, None, '2017-11-09 00:00:00', '2017-11-13 23:23:05'),
#  ('1ce9388b1a3ad76f5f1a64f208a90fce', 'ac7a92560a9e99f0a0ab4988102f491b', 1, None, 'O prazo era até dia 23/03 e até o momento não recebi. Quero saber o que está acontecendo.', '2018-03-25 00:00:00', '2018-03-25 21:40:11'),
#  ('1ce9388b1a3ad76f5f1a64f208a90fce', '0d6cc2219ef268358eac3c49b47abca9', 1, None, 'O prazo era até dia 23/03 e até o momento não recebi. Quero saber o que está acontecendo.', '2018-03-25 00:00:00', '2018-03-25 21:40:11'),
#  ('1d5b8cc3cac5888ebfc80a0dcd337f07', '118ec9ddef528c64a545169b898e7699', 1, None, 'Algo aconteceu errado, pois não recebi estes itens. Contudo, já recebi outros itens que comprei na mesma ocasião.\nAguardo um retorno.', '2017-08-02 00:00:00', '2017-08-05 10:23:37'),
#  ('1d5b8cc3cac5888ebfc80a0dcd337f07', 'b3154d5a5a7c0b01993f0768a1fd4b8a', 1, None, 'Algo aconteceu errado, pois não recebi estes itens. Contudo, já recebi outros itens que comprei na mesma ocasião.\nAguardo um retorno.', '2017-08-02 00:00:00', '2017-08-05 10:23:37'),
#  ('1dee9d450a2b8533d2085cef898ca4a2', '7e03de7edf3bc774fd1ad0915464e41b', 5, None, None, '2018-02-06 00:00:00', '2018-02-06 17:19:21'),
#  ('1dee9d450a2b8533d2085cef898ca4a2', '03515a836bb855b03f7df9dee520a8fc', 5, None, None, '2018-02-06 00:00:00', '2018-02-06 17:19:21'),
#  ('1e3fb3520c0e1e9c12b0dc943f7d437b', '2f2ccd40795675eff302804c7cbe24b9', 3, None, None, '2017-06-01 00:00:00', '2017-06-05 16:22:06'),
#  ('1e3fb3520c0e1e9c12b0dc943f7d437b', '73c84b13ab9bb715a8e21eb2329177eb', 3, None, None, '2017-06-01 00:00:00', '2017-06-05 16:22:06'),
#  ('1ed01e8f777018a33227be5073a82e8d', '908c80ba9160e9d87007015b15aada39', 1, None, None, '2017-11-15 00:00:00', '2017-11-15 21:13:33'),
#  ('1ed01e8f777018a33227be5073a82e8d', '67d760ec323d2c9f0292ec4cdafc676e', 1, None, None, '2017-11-15 00:00:00', '2017-11-15 21:13:33'),
#  ('1ed134d3e8e587c1589c338712516757', 'ed63d1955429b2d9b6172c755b4fa1b2', 3, None, None, '2018-03-27 00:00:00', '2018-03-29 22:19:07'),
#  ('1ed134d3e8e587c1589c338712516757', '46b06fc4d4a2d4e9645f19e1a689e543', 3, None, None, '2018-03-27 00:00:00', '2018-03-29 22:19:07'),
#  ('1ef17c31c6a710e3cee7853fb387dcc3', '94153bbf95f273c5b6c342d2acc6d017', 5, None, 'Muito bom os produtos e foi entregs bem antes do prazo', '2017-07-26 00:00:00', '2017-07-27 03:34:07'),
#  ('1ef17c31c6a710e3cee7853fb387dcc3', '9e8bf3ebc81cc29ee6e934d95370e5bc', 5, None, 'Muito bom os produtos e foi entregs bem antes do prazo', '2017-07-26 00:00:00', '2017-07-27 03:34:07'),
#  ('1f1702781508ddd2fc0020f6c691d600', 'adeaede19791cc3d2eb6f340a6249aa7', 5, None, None, '2017-07-13 00:00:00', '2017-07-16 15:19:54'),
#  ('1f1702781508ddd2fc0020f6c691d600', 'a33506544926e8200ef81a92ce3c3280', 5, None, None, '2017-07-13 00:00:00', '2017-07-16 15:19:54'),
#  ('1f5aa5d7c3ee7895e4d223797b5a5f2d', 'c79bdf061e22288609201ec60deb42fb', 5, None, 'Tudo ocorreu de forma eficiente', '2017-05-10 00:00:00', '2017-05-12 00:58:11'),
#  ('1f5aa5d7c3ee7895e4d223797b5a5f2d', '17df2cc060680fc1712991499b645cd2', 5, None, 'Tudo ocorreu de forma eficiente', '2017-05-10 00:00:00', '2017-05-12 00:58:11'),
#  ('1f80ddc1e47fa27e028f8d94684375d8', '3967044b1f033a8b079e050cf79b2586', 5, None, 'Otimo', '2017-12-06 00:00:00', '2017-12-12 11:03:24'),
#  ('1f80ddc1e47fa27e028f8d94684375d8', '69730255ec58c4cf06be03ba4718b994', 5, None, 'Otimo', '2017-12-06 00:00:00', '2017-12-12 11:03:24'),
#  ('1f97f75959fdde611d52fde0a4ef310c', '63bfa2fa974302f74839f89adc439305', 1, None, None, '2018-02-27 00:00:00', '2018-03-02 13:33:55'),
#  ('1f97f75959fdde611d52fde0a4ef310c', '86198e40464e410dbb14a4ae8e03ecbc', 1, None, None, '2018-02-27 00:00:00', '2018-03-02 13:33:55'),
#  ('1f997992c19d44fe5049ec91f13ccd34', '78ac0881f0e98a1afd25f066d5451d70', 3, None, 'Produto demorou muito pra chegar.', '2018-02-15 00:00:00', '2018-02-18 09:19:53'),
#  ('1f997992c19d44fe5049ec91f13ccd34', '4082016610cd8b53add011fe068c04b3', 3, None, 'Produto demorou muito pra chegar.', '2018-02-15 00:00:00', '2018-02-18 09:19:53'),
#  ('1fb4ddc969e6bea80e38deec00393a6f', 'd6dde74bdeb424af6b660214881b4845', 5, None, None, '2017-08-11 00:00:00', '2017-08-12 14:35:35'),
#  ('1fb4ddc969e6bea80e38deec00393a6f', '3c1098cb17277b62cfc709c7a9b500f5', 5, None, None, '2017-08-11 00:00:00', '2017-08-12 14:35:35'),
#  ('1fb4ddc969e6bea80e38deec00393a6f', 'afed4265a8b956d840bc032e54dfccd1', 5, None, None, '2017-08-11 00:00:00', '2017-08-12 14:35:35'),
#  ('202b5f44d09cd3cfc0d6bd12f01b044c', 'c44883fc2529b4aa03ca90e7e09d95b6', 5, None, None, '2017-07-22 00:00:00', '2017-07-26 13:40:22'),
#  ('202b5f44d09cd3cfc0d6bd12f01b044c', 'c88b1d1b157a9999ce368f218a407141', 5, None, None, '2017-07-22 00:00:00', '2017-07-26 13:40:22'),
#  ('20361385529351bec8dbcc659449cf2f', 'fc3ff005fe8350241fc153d6828070c4', 5, None, None, '2018-06-30 00:00:00', '2018-07-02 17:31:21'),
#  ('20361385529351bec8dbcc659449cf2f', '5fbf74426609c2706727d1e358652e36', 5, None, None, '2018-06-30 00:00:00', '2018-07-02 17:31:21'),
#  ('206ac3e1651d98d3a5b41e6b83409168', '3241db830366645e6a88f6384ee36cc7', 4, None, None, '2017-03-15 00:00:00', '2017-03-17 11:08:27'),
#  ('206ac3e1651d98d3a5b41e6b83409168', 'f56ef9a15044d3fcd12867e68415ee5c', 4, None, None, '2017-03-15 00:00:00', '2017-03-17 11:08:27'),
#  ('20dbd899791a670bf2dafabf0243f6ee', '0778ca929f32b5357008bd57489a1272', 3, None, None, '2017-09-02 00:00:00', '2017-09-03 13:38:41'),
#  ('20dbd899791a670bf2dafabf0243f6ee', '431fe12f4d24d8f61a0947c0bc842a04', 3, None, None, '2017-09-02 00:00:00', '2017-09-03 13:38:41'),
#  ('2172867fd5b1a55f98fe4608e1547b4b', 'e11ba7fd8fe0728dcd89efddcda9fb11', 5, None, 'Entrega no prazo e produto de qualidade!', '2018-02-15 00:00:00', '2018-02-26 15:53:18'),
#  ('2172867fd5b1a55f98fe4608e1547b4b', '559d606ac642899e44550f194fec7e08', 5, None, 'Entrega no prazo e produto de qualidade!', '2018-02-15 00:00:00', '2018-02-26 15:53:18'),
#  ('2172867fd5b1a55f98fe4608e1547b4b', 'ac6e61336e852cdc45fe59ada3763a66', 5, None, 'Entrega no prazo e produto de qualidade!', '2018-02-15 00:00:00', '2018-02-26 15:53:18'),
#  ('22a299893c5cee48be41d8fab8804e6e', 'e4fbee33c090a0bb7899c33f71539524', 5, None, None, '2017-06-22 00:00:00', '2017-06-27 19:46:16'),
#  ('22a299893c5cee48be41d8fab8804e6e', '191fa27b2a907e113d60ddfd7dc29696', 5, None, None, '2017-06-22 00:00:00', '2017-06-27 19:46:16'),
#  ('22fef74f256389ce01a0886104f0c490', '57d1548a5e964a5d6d303ff32de7859f', 4, None, None, '2018-03-11 00:00:00', '2018-03-12 23:39:37'),
#  ('22fef74f256389ce01a0886104f0c490', '44cb884118c81bf6db2f43cf11ab63d6', 4, None, None, '2018-03-11 00:00:00', '2018-03-12 23:39:37'),
#  ('239fd569e8da19db25053b848f2d24e4', 'd6af9770d6d713b4c3a4cd6267e9d2ea', 5, None, None, '2018-01-31 00:00:00', '2018-02-04 16:44:30'),
#  ('239fd569e8da19db25053b848f2d24e4', '14d9794bbb53614d12cc2df6a045f82b', 5, None, None, '2018-01-31 00:00:00', '2018-02-04 16:44:30'),
#  ('23a008b7ae9704e3b656a489d9da4681', '6567e0ba7d75594aacbf2ae3bc9a52b4', 1, 'Ruim', 'Produto veio errado', '2018-08-15 00:00:00', '2018-08-20 05:05:29'),
#  ('23a008b7ae9704e3b656a489d9da4681', '9380c59012c11f49c549ef8dffef1367', 1, 'Ruim', 'Produto veio errado', '2018-08-15 00:00:00', '2018-08-20 05:05:29'),
#  ('23b4bc2bed27abb066272d560caa7c5b', '94d97c26cd5ca2a98749be9e672b44d4', 2, None, 'Solicitei a devolução mas já se passaram as 48h e ainda não recebi retorno.', '2017-09-12 00:00:00', '2017-09-15 00:26:56'),
#  ('23b4bc2bed27abb066272d560caa7c5b', '1c961234d514101345679cb6028102fa', 2, None, 'Solicitei a devolução mas já se passaram as 48h e ainda não recebi retorno.', '2017-09-12 00:00:00', '2017-09-15 00:26:56'),
#  ('24a60a24e0fd528dc4386386310a90cb', '46936461f0c4e3c80b9289ce5fc1682a', 1, None, 'Acho que se pago frente tenho que recebero produto na minha residência', '2017-02-16 00:00:00', '2017-02-18 16:42:13'),
#  ('24a60a24e0fd528dc4386386310a90cb', '195416246665b8268100ef5fde9722b4', 1, None, 'Acho que se pago frente tenho que recebero produto na minha residência', '2017-02-16 00:00:00', '2017-02-18 16:42:13'),
#  ('258dc67e9f3802ef26a0ac367bbd8159', '80e2ed9ee8878458ac2191eb469cb0fb', 5, None, None, '2017-06-14 00:00:00', '2017-06-15 23:21:05'),
#  ('258dc67e9f3802ef26a0ac367bbd8159', 'dfc6c80c73f6b324371273bd97e19c3f', 5, None, None, '2017-06-14 00:00:00', '2017-06-15 23:21:05'),
#  ('25bcfebfae00729120768fd9654048ae', '7d7f3cbab666fd1e2f103d28b2c9bc64', 5, None, None, '2017-09-06 00:00:00', '2017-09-11 12:28:04'),
#  ('25bcfebfae00729120768fd9654048ae', '6b331bf7ee3fd56657566f64027c8c88', 5, None, None, '2017-09-06 00:00:00', '2017-09-11 12:28:04'),
#  ('260893353c2400249d80dcd57f34b1cb', 'ce9feeba53c652dd6569cca62e2bb287', 2, None, None, '2018-04-21 00:00:00', '2018-04-24 18:34:40'),
#  ('260893353c2400249d80dcd57f34b1cb', 'e69a5e21c8b1ef4923a65be7357b67f5', 2, None, None, '2018-04-21 00:00:00', '2018-04-24 18:34:40'),
#  ('260b8badf10666253ac8a8eda99119f9', '75d5d3d16567a27eefc5752aeb063072', 1, None, 'Não recebi o pedido completo ,veio faltando 1 jogo de toalhas.Comprei 2 jogos Nota Fiscal 001689. Aguardo solução urgente.Faltou jogo vermelho.Fornecedor Ibitinga Decora.Aguardo solução urgente', '2017-06-01 00:00:00', '2017-06-02 18:29:03'),
#  ('260b8badf10666253ac8a8eda99119f9', '8e350e1e4254bd7c68913b98bde7d3a7', 1, None, 'Não recebi o pedido completo ,veio faltando 1 jogo de toalhas.Comprei 2 jogos Nota Fiscal 001689. Aguardo solução urgente.Faltou jogo vermelho.Fornecedor Ibitinga Decora.Aguardo solução urgente', '2017-06-01 00:00:00', '2017-06-02 18:29:03'),
#  ('260ee32afa3b7b9ed9bc283449dfab75', 'f8e76bb341db0c60411beac8a83f312a', 1, None, 'nao posso avaliar, sem ter recebido', '2017-12-01 00:00:00', '2017-12-05 23:18:43'),
#  ('260ee32afa3b7b9ed9bc283449dfab75', 'f83c07d038cf7ce0132a5797f823e4fe', 1, None, 'nao posso avaliar, sem ter recebido', '2017-12-01 00:00:00', '2017-12-05 23:18:43'),
#  ('268d71995d6c0c472faf0f13b442a00e', '8f22b4b97d1fd2f187f3106ffb0021c4', 1, None, 'Comprei 2 unidades é só chegou uma', '2017-08-11 00:00:00', '2017-08-12 03:34:40'),
#  ('268d71995d6c0c472faf0f13b442a00e', 'ba89a3d7d01c8a2a0bbdb514a851e9f1', 1, None, 'Comprei 2 unidades é só chegou uma', '2017-08-11 00:00:00', '2017-08-12 03:34:40'),
#  ('26c7339968774f98c7b496b924e97913', '6318d8c5f6857de384c0b3186d036457', 5, None, None, '2017-07-08 00:00:00', '2017-07-10 00:17:24'),
#  ('26c7339968774f98c7b496b924e97913', '2d8e4baffe6056f0800c1d99f2960384', 5, None, None, '2017-07-08 00:00:00', '2017-07-10 00:17:24'),
#  ('27577255e325253c41747b9f89ba0322', 'cab6aa158d9699a614d92fb920c9ae3e', 5, None, None, '2018-08-04 00:00:00', '2018-08-05 00:37:35'),
#  ('27577255e325253c41747b9f89ba0322', '3227045c7007663566ae3d19aed8cca7', 5, None, None, '2018-08-04 00:00:00', '2018-08-05 00:37:35'),
#  ('27707bdab4a7b6bb49a2c3bcdf41e995', 'fdc9d53919c301a0d27f2aad205c5aea', 5, None, 'Ainda não enchemos a boia mas a princípio veio tudo certo e no prazo de entrega!!', '2017-12-07 00:00:00', '2017-12-07 20:44:26'),
#  ('27707bdab4a7b6bb49a2c3bcdf41e995', '04eafa8a91ba0d51dc0c193bb67afc87', 5, None, 'Ainda não enchemos a boia mas a princípio veio tudo certo e no prazo de entrega!!', '2017-12-07 00:00:00', '2017-12-07 20:44:26'),
#  ('277f94dbeb08157d18262e06d71d9fd6', '582fd4fa596ee1af88f153a5ba0523f2', 5, None, 'Parabéns', '2017-11-25 00:00:00', '2017-11-29 23:12:50'),
#  ('277f94dbeb08157d18262e06d71d9fd6', 'd4c2efa6a85e5aa02652b1358cc340fd', 5, None, 'Parabéns', '2017-11-25 00:00:00', '2017-11-29 23:12:50'),
#  ('28642ce6250b94cc72bc85960aec6c62', 'bc42a955f289870d5789e6e437206300', 5, None, None, '2018-03-25 00:00:00', '2018-03-25 21:03:02'),
#  ('28642ce6250b94cc72bc85960aec6c62', 'e239d280236cdd3c40cb2c033f681d1c', 5, None, None, '2018-03-25 00:00:00', '2018-03-25 21:03:02'),
#  ('28749be4e9f00ad1305d70a22faa6938', '0fa7c709db9f55e40527c25ec9f13157', 2, None, None, '2018-02-22 00:00:00', '2018-02-23 01:04:51'),
#  ('28749be4e9f00ad1305d70a22faa6938', '4d34da0824213ee7962a5c5ed32b3f51', 2, None, None, '2018-02-22 00:00:00', '2018-02-23 01:04:51'),
#  ('289450935cf7a082af13e04160716ce5', '2ef81da37176cfe633d519636052f2dd', 5, None, 'produto chegou correto , recomendo', '2018-03-25 00:00:00', '2018-03-27 17:57:49'),
#  ('289450935cf7a082af13e04160716ce5', '4fe48790875f264fd93c9009892c3e39', 5, None, 'produto chegou correto , recomendo', '2018-03-25 00:00:00', '2018-03-27 17:57:49'),
#  ('28ab5f5b112efe2a2f4582bf4d070485', '1f4409e522bbd17f0fcc7b9d1409fe8c', 3, None, 'Eu ainda não recebi o produto para avaliviar a nota', '2017-11-11 00:00:00', '2017-11-12 11:15:05'),
#  ('28ab5f5b112efe2a2f4582bf4d070485', '5f4415c3829ad05566ee455a5344d07d', 3, None, 'Eu ainda não recebi o produto para avaliviar a nota', '2017-11-11 00:00:00', '2017-11-12 11:15:05'),
#  ('28ca1ef3654a32df2ec947b123a1385f', '688e3682bd719f71232cc322252fb045', 5, None, None, '2018-03-14 00:00:00', '2018-03-21 21:30:50'),
#  ('28ca1ef3654a32df2ec947b123a1385f', '27ea1775a86c796168b08511e529d0a3', 5, None, None, '2018-03-14 00:00:00', '2018-03-21 21:30:50'),
#  ('28d0d8241ef547ebff745da0b395e7cf', 'e2d87ac3739c08508d0f9a46cf33786f', 5, None, None, '2018-03-14 00:00:00', '2018-03-14 19:38:22'),
#  ('28d0d8241ef547ebff745da0b395e7cf', '3d87ba4f7660501adecd3a4fa95886b2', 5, None, None, '2018-03-14 00:00:00', '2018-03-14 19:38:22'),
#  ('29aeeca2ed21aedc552cc21421eeb983', 'cc2999bc678cab0949b90c4759d7a284', 5, None, None, '2017-07-13 00:00:00', '2017-07-18 00:24:04'),
#  ('29aeeca2ed21aedc552cc21421eeb983', '06b2c7035561ef12b16045ef4bf459e2', 5, None, None, '2017-07-13 00:00:00', '2017-07-18 00:24:04'),
#  ('29c55c384cbf612e098a1734a42592d4', '441c5a5da055ac9043e37bc8b976654f', 4, None, None, '2018-08-22 00:00:00', '2018-08-24 15:11:40'),
#  ('29c55c384cbf612e098a1734a42592d4', '086f617d66181efa193629791e0a9076', 4, None, None, '2018-08-22 00:00:00', '2018-08-24 15:11:40'),
#  ('2a3937850183a3c2fb90ed6a8ae9514c', '37dbd3a9ef03223ca93bad0442fd91ba', 4, None, None, '2017-11-25 00:00:00', '2017-11-27 01:04:46'),
#  ('2a3937850183a3c2fb90ed6a8ae9514c', 'aa0c9cd6b1097927c4caae58b28e5361', 4, None, None, '2017-11-25 00:00:00', '2017-11-27 01:04:46'),
#  ('2a42f23fc65654f83c9e6594f3ef2c23', '3020672893fa4aa5b9a077aef902851e', 5, None, None, '2017-05-25 00:00:00', '2017-05-28 03:26:32'),
#  ('2a42f23fc65654f83c9e6594f3ef2c23', '2c6df2cdea838bd21bc2dc78dac3029b', 5, None, None, '2017-05-25 00:00:00', '2017-05-28 03:26:32'),
#  ('2a74b0559eb58fc1ff842ecc999594cb', 'b50a7d7b24d9089159085f878aecfad0', 5, None, 'Estou acostumada a comprar produtos pelo baratheon. Super confiável, transparência, qualidade e agilidade. Super recomendo.', '2017-08-25 00:00:00', '2017-08-29 21:45:57'),
#  ('2a74b0559eb58fc1ff842ecc999594cb', '0035246a40f520710769010f752e7507', 5, None, 'Estou acostumada a comprar produtos pelo baratheon. Super confiável, transparência, qualidade e agilidade. Super recomendo.', '2017-08-25 00:00:00', '2017-08-29 21:45:57'),
#  ('2afe63a67dfd99b3038f568fb47ee761', '49bab3f94ce298f6fde6208f426978b4', 5, None, 'Muito bom, produto conforme anunciado, entrega antes do prazo.', '2018-03-03 00:00:00', '2018-03-04 22:56:47'),
#  ('2afe63a67dfd99b3038f568fb47ee761', 'c5334d330e36d2a810a7a13c72e135ee', 5, None, 'Muito bom, produto conforme anunciado, entrega antes do prazo.', '2018-03-03 00:00:00', '2018-03-04 22:56:47'),
#  ('2aff17b27e1fa4125d6d9e9800b22d07', 'b8801cccd8068de30112e4f49903d74a', 3, None, 'Tudo em ordem.', '2017-08-02 00:00:00', '2017-08-02 20:06:46'),
#  ('2aff17b27e1fa4125d6d9e9800b22d07', 'd0d30d1f6b48c8e1266d9b960dc191d5', 3, None, 'Tudo em ordem.', '2017-08-02 00:00:00', '2017-08-02 20:06:46'),
#  ('2b7b61d0f37a3b5fc2d61a7cc8424b95', 'de555a095d66fc6e7b5a1131b4e0c31b', 3, None, None, '2017-11-04 00:00:00', '2017-11-06 14:56:46'),
#  ('2b7b61d0f37a3b5fc2d61a7cc8424b95', '41cb9d97fc1bb4dd341d2f383972d178', 3, None, None, '2017-11-04 00:00:00', '2017-11-06 14:56:46'),
#  ('2c264ab8b6507895fa712c330da4fdc0', 'bb112b59b8f03e372acab987c036fbf3', 5, None, None, '2017-12-05 00:00:00', '2017-12-08 14:27:18'),
#  ('2c264ab8b6507895fa712c330da4fdc0', 'cf83caae8eba6306ab83c98f7ce4f063', 5, None, None, '2017-12-05 00:00:00', '2017-12-08 14:27:18'),
#  ('2c6c08892b83ba4c1be33037c2842294', 'd78c16f09da03410837a551a09a4bf64', 4, None, 'Chegou um pouco amassada, mas nada de mais, e chegou antes do prazo.', '2017-07-03 00:00:00', '2017-07-05 19:06:59'),
#  ('2c6c08892b83ba4c1be33037c2842294', '42ae1967f68c90bb325783ac55d761ce', 4, None, 'Chegou um pouco amassada, mas nada de mais, e chegou antes do prazo.', '2017-07-03 00:00:00', '2017-07-05 19:06:59'),
#  ('2cef8ea456a6210da27879af5b05a82b', '0dccb365ad960364b43a228ff6cebd3b', 5, None, 'Entregou o produto no prazo, bom preço.', '2018-03-03 00:00:00', '2018-03-04 12:53:32'),
#  ('2cef8ea456a6210da27879af5b05a82b', '6f78a74ebcd33afa2bccc0c0a82ff04a', 5, None, 'Entregou o produto no prazo, bom preço.', '2018-03-03 00:00:00', '2018-03-04 12:53:32'),
#  ('2d6ac45f859465b5c185274a1c929637', '41c284ffd871324eadf06fc989583619', 1, None, 'Comprei 3 unidades do produto vieram 2 unidades que não corresponde com o que comprei. Devido a minha opinião é negativa com relação a esse vendedor pois não não cumpriu com o prometido na venda.', '2018-04-07 00:00:00', '2018-04-07 21:13:05'),
#  ('2d6ac45f859465b5c185274a1c929637', 'ef66cc60de5221417b5fb81b1c42de85', 1, None, 'Comprei 3 unidades do produto vieram 2 unidades que não corresponde com o que comprei. Devido a minha opinião é negativa com relação a esse vendedor pois não não cumpriu com o prometido na venda.', '2018-04-07 00:00:00', '2018-04-07 21:13:05'),
#  ('2d6ac45f859465b5c185274a1c929637', '8e17072ec97ce29f0e1f111e598b0c85', 1, None, 'Comprei 3 unidades do produto vieram 2 unidades que não corresponde com o que comprei. Devido a minha opinião é negativa com relação a esse vendedor pois não não cumpriu com o prometido na venda.', '2018-04-07 00:00:00', '2018-04-07 21:13:05'),
#  ('2e19e3dd6600cd67f04d70845b6f6994', '7c971e779cf367c04e3621cc1b81e352', 4, None, None, '2018-03-16 00:00:00', '2018-03-19 02:40:13'),
#  ('2e19e3dd6600cd67f04d70845b6f6994', '6b2f7dba402cf63ca207bbe2cc05ef67', 4, None, None, '2018-03-16 00:00:00', '2018-03-19 02:40:13'),
#  ('30153632ebb19a673c80aa1b13e94c3d', '6cbe792e9ab88ffb6579d0b28088a988', 4, None, None, '2017-09-13 00:00:00', '2017-09-14 14:10:09'),
#  ('30153632ebb19a673c80aa1b13e94c3d', '7139a3b215ea730e2db624cc99820578', 4, None, None, '2017-09-13 00:00:00', '2017-09-14 14:10:09'),
#  ('3052a79d76a1932ff98c990a59230f8d', '241ed1aad96c4cc788ee6f8ab96242ef', 5, None, None, '2018-01-23 00:00:00', '2018-01-24 00:17:19'),
#  ('3052a79d76a1932ff98c990a59230f8d', 'dbfa3d8c05cc5d84083fc259a9feb5bc', 5, None, None, '2018-01-23 00:00:00', '2018-01-24 00:17:19'),
#  ('308316408775d1600dad81bd3184556d', '27e5ed2ecefbe0bcc9ae0c9b26b763c3', 5, None, 'Ajudem a rastrear uma das 3 prateleiras que faltou, só chegaram 2 delas...', '2017-09-07 00:00:00', '2017-09-11 09:58:09'),
#  ('308316408775d1600dad81bd3184556d', '8b3c2785144e72ccba9b0213f0f1cd1e', 5, None, 'Ajudem a rastrear uma das 3 prateleiras que faltou, só chegaram 2 delas...', '2017-09-07 00:00:00', '2017-09-11 09:58:09'),
#  ('308316408775d1600dad81bd3184556d', '3fe4dbcdb046a475dbf25463c1ca78bd', 5, None, 'Ajudem a rastrear uma das 3 prateleiras que faltou, só chegaram 2 delas...', '2017-09-07 00:00:00', '2017-09-11 09:58:09'),
# ...
#  ('8de4e497d8b04d638b0f09159c34afd2', '2c6df2cdea838bd21bc2dc78dac3029b', 5, None, None, '2017-05-25 00:00:00', '2017-05-28 03:26:02'),
#  ('8de59983eadc752efaf5e7c5b4b46787', '5bd39e6a06371941eb585cbe79b41efc', 2, 'Produto veio diferente', 'O produto que pedi veio numa numeração diferente da que havia pedido', '2018-08-08 00:00:00', '2018-08-08 22:49:30'),
#  ('8de59983eadc752efaf5e7c5b4b46787', 'c021ea4a80ce0d1bce358a2f831c34db', 2, 'Produto veio diferente', 'O produto que pedi veio numa numeração diferente da que havia pedido', '2018-08-08 00:00:00', '2018-08-08 22:49:30'),
#  ('8e6867391ed88ac3c579b4e73ff72ce9', '5a43808d42753320e279399cef4c3282', 1, None, 'nao recomendo pq nem se quer me perguntaram a cor dos ursinhos na hora da comprar cliquei no rosa e veio azul .e agora dinheiro posto fora pois estou gravida de menina', '2017-08-24 00:00:00', '2017-08-25 11:25:53'),
#  ('8e6867391ed88ac3c579b4e73ff72ce9', 'ca621c614abfc6d64f4a093ade1249b9', 1, None, 'nao recomendo pq nem se quer me perguntaram a cor dos ursinhos na hora da comprar cliquei no rosa e veio azul .e agora dinheiro posto fora pois estou gravida de menina', '2017-08-24 00:00:00', '2017-08-25 11:25:53'),
#  ('8e82db2cf69e84e85e7d15e888d0790a', 'f2f994648283ef31bf69ae8b9109921c', 4, None, None, '2017-12-17 00:00:00', '2017-12-19 17:54:50'),
#  ('8e82db2cf69e84e85e7d15e888d0790a', '5559edd02dabfec0a6ee808960297d1b', 4, None, None, '2017-12-17 00:00:00', '2017-12-19 17:54:50'),
#  ('8e954c79dc2fc426d5f17035e9bb22dd', '0e69198c87f4da026d7daf96d91b194d', 1, None, 'Estou aguardando a entrega do produto.', '2017-05-22 00:00:00', '2017-05-22 19:19:11'),
#  ('8e954c79dc2fc426d5f17035e9bb22dd', '08c01d43e93f5c485f48758550d41eb9', 1, None, 'Estou aguardando a entrega do produto.', '2017-05-22 00:00:00', '2017-05-22 19:19:11'),
#  ('8ee90ac383cf825bb7f4756130d4e74a', '8e350e1e4254bd7c68913b98bde7d3a7', 5, None, 'recomendo', '2017-05-30 00:00:00', '2017-06-02 18:16:17'),
#  ('8ee90ac383cf825bb7f4756130d4e74a', '75d5d3d16567a27eefc5752aeb063072', 5, None, 'recomendo', '2017-05-30 00:00:00', '2017-06-02 18:16:17'),
#  ('8f5b66ebafa5c69767c42dfeacfb4c86', 'dbf76ef1323584fa387945f83b324534', 5, None, None, '2017-10-11 00:00:00', '2017-10-15 20:47:19'),
#  ('8f5b66ebafa5c69767c42dfeacfb4c86', 'd3d6788577c9592da441752e8a1dd5e3', 5, None, None, '2017-10-11 00:00:00', '2017-10-15 20:47:19'),
#  ('8f88d933e21e08599ea3e88e6e63b2b9', '824fa8179b9911d58831e0b09eedde13', 1, None, 'Eu compro muito pela net. E este não recebi', '2017-08-10 00:00:00', '2017-08-13 07:12:02'),
#  ('8f88d933e21e08599ea3e88e6e63b2b9', '6066fbcebeaf378770ad9fbe8e30d1f0', 1, None, 'Eu compro muito pela net. E este não recebi', '2017-08-10 00:00:00', '2017-08-13 07:12:02'),
#  ('8fc3ad1229b19f354e7996b447111458', '8265a551f1441d4dd75468036a7a5020', 4, None, None, '2017-08-31 00:00:00', '2017-09-01 14:51:37'),
#  ('8fc3ad1229b19f354e7996b447111458', '4f2a73bfb26889724652d46145c4a62f', 4, None, None, '2017-08-31 00:00:00', '2017-09-01 14:51:37'),
#  ('8fca97544a1d5a56a7077b1b9f9c6df7', 'ceb533871105f7cda81fafc19e1ee38e', 1, None, None, '2017-11-15 00:00:00', '2017-11-30 14:37:47'),
#  ('8fca97544a1d5a56a7077b1b9f9c6df7', 'e58fb7bfd033514475ab0883ded704f4', 1, None, None, '2017-11-15 00:00:00', '2017-11-30 14:37:47'),
#  ('90367ad2293f2aa1e402c2f98e14c774', '20824837882dd673707e0adfcaec1bc1', 5, None, None, '2017-11-04 00:00:00', '2017-11-05 13:41:29'),
#  ('90367ad2293f2aa1e402c2f98e14c774', '8d9bd5e3d8b2ac2fa02f79f8dd382db0', 5, None, None, '2017-11-04 00:00:00', '2017-11-05 13:41:29'),
#  ('90514cec532749be9a0a0f16d21e4ab5', '198d82e095bb34f33adaea72cfd63885', 4, None, 'prevaleça sempre á pontualidade... e comprometimento....', '2017-06-24 00:00:00', '2017-06-27 03:03:06'),
#  ('90514cec532749be9a0a0f16d21e4ab5', '3deb7346dbaa00ea4431f0d97a6ce758', 4, None, 'prevaleça sempre á pontualidade... e comprometimento....', '2017-06-24 00:00:00', '2017-06-27 03:03:06'),
#  ('917a4b765108017eaac1d80971e8f1b7', 'b5a801d2465c927e096449f176459916', 4, None, None, '2017-05-24 00:00:00', '2017-05-25 08:48:42'),
#  ('917a4b765108017eaac1d80971e8f1b7', '677cebcf344bca22b07250e7548bd8bc', 4, None, None, '2017-05-24 00:00:00', '2017-05-25 08:48:42'),
#  ('917cdadc1a5b4cf4c988d264992f23a9', 'c7e1e46af92704b1c2e1924de96e7479', 3, 'Recomendo', 'Recebi o produto errado.', '2018-06-06 00:00:00', '2018-06-07 13:53:24'),
#  ('917cdadc1a5b4cf4c988d264992f23a9', '7144ca093cbdecfdfc3e76d49da6ffb9', 3, 'Recomendo', 'Recebi o produto errado.', '2018-06-06 00:00:00', '2018-06-07 13:53:24'),
#  ('91e35f707b1826ab431e01cdbf99c499', '2683346722c6565c6c79e08c8264f25f', 3, None, None, '2017-09-17 00:00:00', '2017-09-19 14:49:57'),
#  ('91e35f707b1826ab431e01cdbf99c499', 'fccc01060b3a8f4c458f942871da6bd8', 3, None, None, '2017-09-17 00:00:00', '2017-09-19 14:49:57'),
#  ('9216f81424452eb18e3ad1bb6f4a5028', 'ec0dc4b572563095782c3e96a9f4d205', 5, None, None, '2017-07-28 00:00:00', '2017-07-28 23:37:20'),
#  ('9216f81424452eb18e3ad1bb6f4a5028', '0da7c9db070f692a9851de83c90a4371', 5, None, None, '2017-07-28 00:00:00', '2017-07-28 23:37:20'),
#  ('9282f8481d3fff93b5fc444eb5c934e2', 'c0800c1006480bed22d5ec0b593c2cd0', 4, None, 'Produto top pra quem que apaixonado por fazer drinks, recomendo o produto e a loja tbm que entregou no até antes do prazo.', '2017-03-16 00:00:00', '2017-03-20 17:38:20'),
#  ('9282f8481d3fff93b5fc444eb5c934e2', 'bc8446f693e6c406e28d5cee739dc4cd', 4, None, 'Produto top pra quem que apaixonado por fazer drinks, recomendo o produto e a loja tbm que entregou no até antes do prazo.', '2017-03-16 00:00:00', '2017-03-20 17:38:20'),
#  ('938a61beb270ef1e023813b73378f65a', '0f121110b75ef7c38c79d67833c49830', 4, None, None, '2017-10-11 00:00:00', '2017-10-11 23:26:20'),
#  ('938a61beb270ef1e023813b73378f65a', '3d0a2787777e731001936c8a443b22fb', 4, None, None, '2017-10-11 00:00:00', '2017-10-11 23:26:20'),
#  ('93b68340651eee033046dcdd7520d70e', '18706eb4e0b3e500ece5690acaefb220', 1, None, None, '2018-03-11 00:00:00', '2018-03-11 12:02:56'),
#  ('93b68340651eee033046dcdd7520d70e', '1bf4871c57b8284ca1dfa1a02ad278c6', 1, None, None, '2018-03-11 00:00:00', '2018-03-11 12:02:56'),
#  ('93f58f5b658e3b49be2cd83f02a01a9c', '3c40398038e198e9e1636c1116378da8', 5, None, None, '2018-03-29 00:00:00', '2018-03-29 13:39:28'),
#  ('93f58f5b658e3b49be2cd83f02a01a9c', '6c3b9813e98d409d3af5da143efbd2d7', 5, None, None, '2018-03-29 00:00:00', '2018-03-29 13:39:28'),
#  ('943539772eec674741b3a45d6dcf23b9', 'cdf2839409d0f62e2b2e61b62b72dc16', 5, None, None, '2018-02-27 00:00:00', '2018-02-27 19:36:21'),
#  ('943539772eec674741b3a45d6dcf23b9', '6a4b5d63051de8243001f5daa42383f1', 5, None, None, '2018-02-27 00:00:00', '2018-02-27 19:36:21'),
#  ('948654feaf0ba06f55958dc75fe2ac1d', '4d9a297fbfa9ba6d8d70c06d4bec9ca9', 3, None, None, '2017-02-25 00:00:00', '2017-03-09 00:30:40'),
#  ('948654feaf0ba06f55958dc75fe2ac1d', 'c3ec5c70256966fe8951602e15e63495', 3, None, None, '2017-02-25 00:00:00', '2017-03-09 00:30:40'),
#  ('9487a43f29708b00c4b6ef5af2441d1f', '99154e0d0a403c1c7dc3f38886f6776b', 1, None, None, '2017-09-07 00:00:00', '2017-09-13 09:52:05'),
#  ('9487a43f29708b00c4b6ef5af2441d1f', '565b0bdb5bfef65df5a23890967586f6', 1, None, None, '2017-09-07 00:00:00', '2017-09-13 09:52:05'),
#  ('94a66e984d861076b3fba9a0902682a5', '18fdcbdf78e62bac03cf30b6b9398087', 4, None, None, '2017-06-08 00:00:00', '2017-06-11 03:58:07'),
#  ('94a66e984d861076b3fba9a0902682a5', 'f6a3c840a4982c53155907a2fb3b8318', 4, None, None, '2017-06-08 00:00:00', '2017-06-11 03:58:07'),
#  ('94abc85a970d230e11ee2bf1c1071d47', '9c9353e8fd52f68f8442e580b5f2bba6', 1, None, None, '2018-03-23 00:00:00', '2018-03-27 23:14:17'),
#  ('94abc85a970d230e11ee2bf1c1071d47', '4c8eac76de32572cebc64aca0f263e2a', 1, None, None, '2018-03-23 00:00:00', '2018-03-27 23:14:17'),
#  ('94b9eac694c93fb28d6e2fae6426cda9', 'b5a801d2465c927e096449f176459916', 5, None, None, '2017-05-24 00:00:00', '2017-05-25 08:47:55'),
#  ('94b9eac694c93fb28d6e2fae6426cda9', '677cebcf344bca22b07250e7548bd8bc', 5, None, None, '2017-05-24 00:00:00', '2017-05-25 08:47:55'),
#  ('957011305e7a4b6c8a266eeeb8e0316d', '54b4da510fed5dc3cf3e7a8e50a5f224', 4, None, None, '2018-03-10 00:00:00', '2018-03-10 23:35:51'),
#  ('957011305e7a4b6c8a266eeeb8e0316d', 'ccd4eb95e68cb64e666ddcb84f8dfb1e', 4, None, None, '2018-03-10 00:00:00', '2018-03-10 23:35:51'),
#  ('95a3135743556b117d888cc8c6e12e11', 'f9c78e6e58306dc81efbbada1ac11f24', 3, None, 'O produto chegou antes do prazo mas recebi um produto diferente do que mostrados na descrição e nas imagens. Uma das lampadas esta com problema\n\nFizemos uma notificação e estamos aguardando o retorn', '2017-09-14 00:00:00', '2017-09-17 11:14:08'),
#  ('95a3135743556b117d888cc8c6e12e11', '1f80ad89393a17282085bcd14644e45a', 3, None, 'O produto chegou antes do prazo mas recebi um produto diferente do que mostrados na descrição e nas imagens. Uma das lampadas esta com problema\n\nFizemos uma notificação e estamos aguardando o retorn', '2017-09-14 00:00:00', '2017-09-17 11:14:08'),
#  ('95cfb15ad3477fec574b561d1daea972', '4ed4a6e12e74982dd78c78df1ed3f372', 1, None, 'Produto veio com defeito', '2017-08-09 00:00:00', '2017-08-11 01:29:09'),
#  ('95cfb15ad3477fec574b561d1daea972', 'fc24613395700f29adf22b2383c12bb0', 1, None, 'Produto veio com defeito', '2017-08-09 00:00:00', '2017-08-11 01:29:09'),
#  ('97611a5acbeac2d3adb5a731bad57eb2', '24a562b69731cbec7439c1752c500f82', 1, None, None, '2018-03-17 00:00:00', '2018-03-20 00:29:06'),
#  ('97611a5acbeac2d3adb5a731bad57eb2', 'b12e6c26723c864922c152d097c3e87e', 1, None, None, '2018-03-17 00:00:00', '2018-03-20 00:29:06'),
#  ('9840563f4c2189d0a14431a79cd92b16', '6540a36b3dd6a4a0922d5f57d493d9d6', 5, None, None, '2018-02-15 00:00:00', '2018-02-15 20:41:11'),
#  ('9840563f4c2189d0a14431a79cd92b16', 'b91486041622a3542a1c4b44865a4eaa', 5, None, None, '2018-02-15 00:00:00', '2018-02-15 20:41:11'),
#  ('988f510e4dc95095d23bd3eecd9087bc', '328d856c33d24e8aac1b90367ae7cd3a', 5, None, None, '2018-03-15 00:00:00', '2018-03-28 15:19:13'),
#  ('988f510e4dc95095d23bd3eecd9087bc', '43de756a962b59796a31a894bf9b37df', 5, None, None, '2018-03-15 00:00:00', '2018-03-28 15:19:13'),
#  ('98a3d398350fe29005e23133e52dbe46', 'dcd7bf0e4548b5a99e81cca7a7160042', 5, None, None, '2017-08-09 00:00:00', '2017-08-10 13:48:34'),
#  ('98a3d398350fe29005e23133e52dbe46', 'e22de883eaec82ecd47950dffc8e63f4', 5, None, None, '2017-08-09 00:00:00', '2017-08-10 13:48:34'),
#  ('98b82041d04be209faccad4c453ce72d', '2823ed00ae59fbfb1749e613d3888384', 5, None, None, '2018-03-10 00:00:00', '2018-03-11 01:57:39'),
#  ('98b82041d04be209faccad4c453ce72d', '1e077c24035d25ddca3736f56d3e19a8', 5, None, None, '2018-03-10 00:00:00', '2018-03-11 01:57:39'),
#  ('98ee53c394ad7d39a800e8b1c004b44a', '8f5fac100b291e3c7c7c34ca50001b5a', 4, None, None, '2017-12-07 00:00:00', '2017-12-08 13:08:22'),
#  ('98ee53c394ad7d39a800e8b1c004b44a', 'ab97ff9b268ca7e6f9f741cd843363e3', 4, None, None, '2017-12-07 00:00:00', '2017-12-08 13:08:22'),
#  ('9979f9019b0fb7755be14008181a96be', '7f3eeda083f7dd3143b24b17ad4ad881', 5, None, 'MEU PRODUTO VEIO ERRADO.\n\nPAGUEI CASAL KING R$ 99,00 - NÂO CASAL PADRAO. QUERO TROCA URGENTE.', '2018-02-01 00:00:00', '2018-02-05 11:48:12'),
#  ('9979f9019b0fb7755be14008181a96be', '0db395d667c4793655380026bad4a072', 5, None, 'MEU PRODUTO VEIO ERRADO.\n\nPAGUEI CASAL KING R$ 99,00 - NÂO CASAL PADRAO. QUERO TROCA URGENTE.', '2018-02-01 00:00:00', '2018-02-05 11:48:12'),
#  ('9a07cb8136a1792e7984d827e2336d60', 'a229f8f10db36361d958831698ea6e68', 5, None, 'lannister sempre cumpre o prazo de entrega.', '2017-03-31 00:00:00', '2017-04-03 11:12:10'),
#  ('9a07cb8136a1792e7984d827e2336d60', '9db84495f43c7c241929f3c0380dc27b', 5, None, 'lannister sempre cumpre o prazo de entrega.', '2017-03-31 00:00:00', '2017-04-03 11:12:10'),
#  ('9a0bb4f51bdc2568e43a1e47457bd8a4', '2be4ffd7d4cce421234db66149a7f749', 5, None, 'Chegou antes do previsto...Fiquei muito satisfeita, produto muito bem embalado, tudo certo.', '2017-08-20 00:00:00', '2017-08-21 21:52:36'),
#  ('9a0bb4f51bdc2568e43a1e47457bd8a4', '79ce453b9e3dc21f91d306eb1df8bb2a', 5, None, 'Chegou antes do previsto...Fiquei muito satisfeita, produto muito bem embalado, tudo certo.', '2017-08-20 00:00:00', '2017-08-21 21:52:36'),
#  ('9a6903152df5382a641ed1a3bb093ed2', '4f2a73bfb26889724652d46145c4a62f', 4, None, None, '2017-08-29 00:00:00', '2017-09-01 14:53:32'),
#  ('9a6903152df5382a641ed1a3bb093ed2', '8265a551f1441d4dd75468036a7a5020', 4, None, None, '2017-08-29 00:00:00', '2017-09-01 14:53:32'),
#  ('9a8884861c6d83bcab8cb26237a83c12', 'c950a394ee0369c853e3a1a55090e287', 5, None, None, '2018-06-04 00:00:00', '2018-06-08 02:59:34'),
#  ('9a8884861c6d83bcab8cb26237a83c12', 'ccfc366f9a65ee1750a938bd18aa489f', 5, None, None, '2018-06-04 00:00:00', '2018-06-08 02:59:34'),
#  ('9a93eaf9096a3c50bba848e77b786743', '6c04516be61ae90e04756c3290c405b7', 5, None, None, '2017-09-29 00:00:00', '2017-09-29 21:11:45'),
#  ('9a93eaf9096a3c50bba848e77b786743', 'b72a8ad380aaa28c3f4b75f754d26def', 5, None, None, '2017-09-29 00:00:00', '2017-09-29 21:11:45'),
#  ('9ab0b4714556d539f954a0f1afa673e9', '022b1f3510a95b396431fec95f5de236', 2, None, 'Péssimo e gosto horrível! Impossível de beber , não desolve! Me sinto arrependida! lannister usei só 1scop gostaria de trocar não faz 7 dias q comprei, tem jeito ?', '2018-03-11 00:00:00', '2018-03-13 22:17:01'),
#  ('9ab0b4714556d539f954a0f1afa673e9', 'e33ae8b905bb0354b42f585bdfd3ab0d', 2, None, 'Péssimo e gosto horrível! Impossível de beber , não desolve! Me sinto arrependida! lannister usei só 1scop gostaria de trocar não faz 7 dias q comprei, tem jeito ?', '2018-03-11 00:00:00', '2018-03-13 22:17:01'),
#  ('9b0e89862fcb8419c30f3f290e770db1', '2ccde1e4676c20b9444e2bcbed36334c', 5, None, 'Amo esse baratheon....', '2017-06-23 00:00:00', '2017-07-01 11:42:49'),
#  ('9b0e89862fcb8419c30f3f290e770db1', '76de574e14e58baded25a12dce8075c1', 5, None, 'Amo esse baratheon....', '2017-06-23 00:00:00', '2017-07-01 11:42:49'),
#  ('9b88af6ae32a1454e91559508c33ab6e', '8ad14ad7dd26465b377d99c9e26eb76f', 1, None, 'Não recebi o meu produto e gostaria de saber porque!?', '2017-12-21 00:00:00', '2017-12-22 02:36:57'),
#  ('9b88af6ae32a1454e91559508c33ab6e', 'c0825f7ad51d670d765525e6761dbc0d', 1, None, 'Não recebi o meu produto e gostaria de saber porque!?', '2017-12-21 00:00:00', '2017-12-22 02:36:57'),
#  ('9b8b92180c3df43693e67fd100605a9f', '6232b520aa859c47ba46e5213737f418', 5, 'Bom', 'Gostei otimo produto', '2018-06-23 00:00:00', '2018-06-23 22:19:32'),
#  ('9b8b92180c3df43693e67fd100605a9f', 'f1a8e3250a46ef66707b6b0e103c3140', 5, 'Bom', 'Gostei otimo produto', '2018-06-23 00:00:00', '2018-06-23 22:19:32'),
#  ('9bd0077d08645b60245d5f6b8896bbd7', '142b0e3de54c110a3109b26c79d6ec2e', 5, None, None, '2017-07-12 00:00:00', '2017-07-12 23:08:09'),
#  ('9bd0077d08645b60245d5f6b8896bbd7', '7e3e92dc3eaf5389f32da97228f7dd0e', 5, None, None, '2017-07-12 00:00:00', '2017-07-12 23:08:09'),
#  ('9d7b240dff5539983f5def389e2c1bf7', 'a3f048db7f6523ded5c260c1ea0bf007', 5, None, 'Adorei a cortina', '2017-08-09 00:00:00', '2017-08-10 10:58:56'),
#  ('9d7b240dff5539983f5def389e2c1bf7', '2dc5ca4f77839266648dbc98c8c13142', 5, None, 'Adorei a cortina', '2017-08-09 00:00:00', '2017-08-10 10:58:56'),
#  ('9da0796858da97acd8b67578388a3241', 'fe041ba1c9f54016432fa6ee91709dbc', 5, None, 'O cartucho está estourado (vazando), já contatei a empresa. Foi-me informado que haverá a troca!', '2017-12-20 00:00:00', '2017-12-20 22:03:18'),
#  ('9da0796858da97acd8b67578388a3241', 'bc5f75667672b3ffd7dd4daea8c408ce', 5, None, 'O cartucho está estourado (vazando), já contatei a empresa. Foi-me informado que haverá a troca!', '2017-12-20 00:00:00', '2017-12-20 22:03:18'),
#  ('9dc50077272395ec4c7dcf0ff89be4fa', 'c5a468ae781ffb0ec6d36ae89fe512b0', 5, None, 'Super Recomendo..Um encanto :-)', '2017-01-21 00:00:00', '2017-01-23 09:57:30'),
#  ('9dc50077272395ec4c7dcf0ff89be4fa', '4fe2e8b329e56a00aba9b0136b46f00f', 5, None, 'Super Recomendo..Um encanto :-)', '2017-01-21 00:00:00', '2017-01-23 09:57:30'),
#  ...]

# %%
# %%sql
# -- Check for certain values for more investigation
# SELECT *
# FROM order_items
# WHERE order_id in ('d75cb3755738c4ae466303358f97bc55', '0068c109948b9a1dfb8530d1978acef3');
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 3 rows affected.
# [('0068c109948b9a1dfb8530d1978acef3', 1, '525f8fbde09c9bf777025c3141fbbc6e', '8b321bb669392f5163d04c59e235e066', '2018-01-30 02:53:04', Decimal('35.90'), Decimal('15.79')),
#  ('0068c109948b9a1dfb8530d1978acef3', 2, '525f8fbde09c9bf777025c3141fbbc6e', '8b321bb669392f5163d04c59e235e066', '2018-01-30 02:53:04', Decimal('35.90'), Decimal('15.79')),
#  ('d75cb3755738c4ae466303358f97bc55', 1, '474bb6b54fc608ca71059a6c4f7ecda3', '8b321bb669392f5163d04c59e235e066', '2018-01-30 02:53:17', Decimal('21.90'), Decimal('15.79'))]

# %% [markdown]
# Notice that some reviews are identical for differnet orders, This needs more investigation.

# %%
# Now I'm creating a primary key for the order_reviews table
# %sql Alter table order_reviews ADD primary key (review_id, order_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>5- Order items table<FONT/>

# %%
# %sql SELECT * FROM order_items LIMIT 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('00010242fe8c5a6d1ba2dd792cb16214', 1, '4244733e06e7ecb4970a6e2683c13e61', '48436dade18ac8b2bce089ec2a041202', '2017-09-19 09:45:35', Decimal('58.90'), Decimal('13.29')),
#  ('00018f77f2f0320c557190d7a144bdd3', 1, 'e5f2d52b802189ee658865ca93d83a8f', 'dd7ddc04e1b6c2c614352b383efe2d36', '2017-05-03 11:05:13', Decimal('239.90'), Decimal('19.93')),
#  ('000229ec398224ef6ca0657da4fc703e', 1, 'c777355d18b72b67abbeef9df44fd0fd', '5b51032eddd242adc84c38acab88f23d', '2018-01-18 14:48:30', Decimal('199.00'), Decimal('17.87')),
#  ('00024acbcdf0a6daa1e931b038114c75', 1, '7634da152a4610f1595efa32f14722fc', '9d7a1d34a5052409006425275ba1c2b4', '2018-08-15 10:10:18', Decimal('12.99'), Decimal('12.79')),
#  ('00042b26cf59d7ce69dfabb4e55b4fd9', 1, 'ac6c3623068f30de03045865e4e10089', 'df560393f3a51e74553ab94004ba5c87', '2017-02-13 13:57:51', Decimal('199.90'), Decimal('18.14'))]

# %%
# %sql SELECT COUNT(order_id), COUNT(DISTINCT order_id, product_id), COUNT(DISTINCT order_id, product_id, seller_id) FROM order_items
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(112650, 102425, 102425)]

# %% [markdown]
# From the previous result set it's clear that we have duplicates in this table.
# After removing duplicates we'll assign the compination of order_id, product id as a primary key.

# %%
# %%sql
# -- Check if the join with distinct values return the right row count 102425 as in the previous query.
# SELECT COUNT(*)
# FROM
# (SELECT
#     order_id,
#     order_item_id,
#     product_id,
#     seller_id,
#     shipping_limit_date,
#     price,
#     freight_value,
#     ROW_NUMBER() OVER (PARTITION BY order_id, product_id ORDER BY order_id, product_id) AS rn
#
# FROM
#     order_items) as desired_table
# WHERE rn = 1
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(102425,)]

# %%
# %%sql
# -- The code is returning the desired output now we will create that contains the rows with unique (order_id, product_id)
#
# Create table oi as(
# SELECT *
# FROM
# (SELECT
#     order_id,
#     order_item_id,
#     product_id,
#     seller_id,
#     shipping_limit_date,
#     price,
#     freight_value,
#     ROW_NUMBER() OVER (PARTITION BY order_id, product_id ORDER BY order_id, product_id) AS rn
#
# FROM
#     order_items) as desired_table
# WHERE rn = 1
# )

# %% [markdown]
#  Now remove the old table and rename the new one with the desired name(oeder_items)

# %%
# %sql DROP TABLE order_items;

# %%
# %sql ALTER TABLE oi RENAME order_items

# %%
# Now I'm creating a primary key for the order_items table
# %sql Alter table order_items ADD primary key (order_id, product_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>6- Products table<FONT/>

# %%
# %sql SELECT * FROM products limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('1e9e8ef04dbcff4541ed26657ea517e5', 'perfumaria', '40', '287', '1', '225', '16', '10', '14'),
#  ('3aa071139cb16b67ca9e5dea641aaa2f', 'artes', '44', '276', '1', '1000', '30', '18', '20'),
#  ('96bd76ec8810374ed1b65e291975717f', 'esporte_lazer', '46', '250', '1', '154', '18', '9', '15'),
#  ('cef67bcfe19066a932b7673e239eb23d', 'bebes', '27', '261', '1', '371', '26', '4', '26'),
#  ('9dc1a7de274444849c219cff195d0b71', 'utilidades_domesticas', '37', '402', '4', '625', '20', '17', '13')]

# %%
# %%sql
#
# SELECT
#     COUNT(product_id),
#     COUNT(DISTINCT product_id)
#
# FROM products;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(32951, 32951)]

# %% [markdown]
# As you see there is no duplicates the column is ready to be assigned as a primary key.

# %%
# Now I'm creating a primary key for the order_items table
# %sql Alter table products ADD primary key (product_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>7- Order payments table<FONT/>

# %%
# %sql SELECT * FROM order_payments limit 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('b81ef226f3fe1789b1e8b2acac839d17', 1, 'credit_card', 8, Decimal('99.33')),
#  ('a9810da82917af2d9aefd1278f1dcfa0', 1, 'credit_card', 1, Decimal('24.39')),
#  ('25e8ea4e93396b6fa0d3dd708e76c1bd', 1, 'credit_card', 1, Decimal('65.71')),
#  ('ba78997921bbcdc1373bb41e913ab953', 1, 'credit_card', 8, Decimal('107.78')),
#  ('42fdf880ba16b47b59251dd489d4441a', 1, 'credit_card', 2, Decimal('128.45'))]

# %%
# %sql SELECT COUNT(order_id), COUNT( DISTINCT order_id) FROM order_payments
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(103886, 99440)]

# %% [markdown]
# So as you see some orders are mentioned more than once, Lets check them.

# %%
# %%sql
#
#
# SELECT *
#
# FROM
#     order_payments
#
# WHERE order_id in (SELECT
#                        order_id
#                    FROM
#                        order_payments
#                    GROUP BY
#                        order_id
#                    HAVING
#                       COUNT(order_id) > 1)
# ORDER BY order_id
# LIMIT 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 10 rows affected.
# [('0016dfedd97fc2950e388d2971d718c7', 2, 'voucher', 1, Decimal('17.92')),
#  ('0016dfedd97fc2950e388d2971d718c7', 1, 'credit_card', 5, Decimal('52.63')),
#  ('002f19a65a2ddd70a090297872e6d64e', 1, 'voucher', 1, Decimal('44.11')),
#  ('002f19a65a2ddd70a090297872e6d64e', 2, 'voucher', 1, Decimal('33.18')),
#  ('0071ee2429bc1efdc43aa3e073a5290e', 1, 'voucher', 1, Decimal('100.00')),
#  ('0071ee2429bc1efdc43aa3e073a5290e', 2, 'voucher', 1, Decimal('92.44')),
#  ('009ac365164f8e06f59d18a08045f6c4', 5, 'voucher', 1, Decimal('8.75')),
#  ('009ac365164f8e06f59d18a08045f6c4', 1, 'credit_card', 1, Decimal('0.88')),
#  ('009ac365164f8e06f59d18a08045f6c4', 2, 'voucher', 1, Decimal('4.50')),
#  ('009ac365164f8e06f59d18a08045f6c4', 6, 'voucher', 1, Decimal('4.17'))]

# %%
# %sql SELECT COUNT(*), COUNT( DISTINCT order_id, payment_sequential) FROM order_payments
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(103886, 103886)]

# %% [markdown]
# As you see it's normal that an order in mentioned more than once, other attributes changes.
# Which indicates that the order maybe paid with different methods and with many payments.

# %%
# Now I'm creating a primary key for the order_payments table
# %sql Alter table order_payments ADD primary key (order_id, payment_sequential);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>8- Sellers table<FONT/>

# %%
# %sql SELECT * FROM sellers limit 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('3442f8959a84dea7ee197c632cb2df15', 13023, 'campinas', 'SP'),
#  ('d1b65fc7debc3361ea86b5f14c68d2e2', 13844, 'mogi guacu', 'SP'),
#  ('ce3ad9de960102d0677a81f5d0bb7b2d', 20031, 'rio de janeiro', 'RJ'),
#  ('c0f3eea2e14555b6faeea3dd58c1b1c3', 4195, 'sao paulo', 'SP'),
#  ('51a04a8a6bdcb23deccc82b0b80742cf', 12914, 'braganca paulista', 'SP')]

# %%
# %sql SELECT COUNT(seller_id), COUNT(DISTINCT seller_id) FROM sellers;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(3095, 3095)]

# %%
# Now I'm creating a primary key for the sellers table
# %sql Alter table sellers ADD primary key (seller_id);

# %%
# %sql describe sellers
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 4 rows affected.
# [('seller_id', 'varchar(32)', 'NO', 'PRI', None, ''),
#  ('seller_zip_code_prefix', 'int', 'NO', '', None, ''),
#  ('seller_city', 'varchar(40)', 'NO', '', None, ''),
#  ('seller_state', 'varchar(2)', 'NO', '', None, '')]

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# ## <FONT color = 'green'>9- sellersproduct_category_name_translation table<FONT/>

# %%
# %sql SELECT * FROM category_translation LIMIT 10;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 10 rows affected.
# [('agro_industria_e_comercio', 'agro_industry_and_commerce'),
#  ('alimentos', 'food'),
#  ('alimentos_bebidas', 'food_drink'),
#  ('artes', 'art'),
#  ('artes_e_artesanato', 'arts_and_craftmanship'),
#  ('artigos_de_festas', 'party_supplies'),
#  ('artigos_de_natal', 'christmas_supplies'),
#  ('audio', 'audio'),
#  ('automotivo', 'auto'),
#  ('bebes', 'baby')]

# %%
# %sql SELECT COUNT(product_category_name), COUNT(DISTINCT product_category_name) FROM category_translation;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 1 rows affected.
# [(71, 71)]

# %%
# Now I'm creating a primary key for the category_translation table
# %sql Alter table category_translation ADD primary key (product_category_name);

# %%
# %sql describe category_translation
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 2 rows affected.
# [('product_category_name', 'varchar(46)', 'NO', 'PRI', None, ''),
#  ('product_category_name_english', 'varchar(39)', 'NO', '', None, '')]

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# _______________________________________________________________________________________________________________________________
# # <FONT color = 'red'>Check the integrity of columns nominated to be foreign keys and creating relationships between tables<FONT/>

# %%
# %sql SHOW TABLES
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 9 rows affected.
# [('category_translation',),
#  ('customers',),
#  ('geolocation',),
#  ('order_items',),
#  ('order_payments',),
#  ('order_reviews',),
#  ('orders',),
#  ('products',),
#  ('sellers',)]

# %% [markdown]
# ### <font color='Indigo'>Desired Schema <font/>
#
# <img src="https://i.imgur.com/HRhd2Y0.png" alt="Desired Schema"/>

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Customers - Geolocation using zip_code_prefix</FONT>

# %%
# %%sql
# ALTER Table geolocation
# RENAME COLUMN `MAX(geolocation_city)` TO geolocation_city,
# RENAME COLUMN `MAX(geolocation_state)` TO geolocation_state;

# %%
# %%sql
#
# ALTER TABLE customers
# ADD CONSTRAINT fk_name1
# FOREIGN KEY (customer_zip_code_prefix)
# REFERENCES geolocation(geolocation_zip_code_prefix)

# %% [markdown]
# there are values in the customers table that does not have reference values in geolocation table.
# Since customer table hav the all columns of the geo table, I'll add values from customers to geolocation.

# %%
# %%sql
# INSERT INTO geolocation
# (
# SELECT
#     customer_zip_code_prefix,
#     MAX(customer_city) as customer_city,
#     MAX(customer_state) as customer_state
# FROM
#     CUSTOMERS
# WHERE
#     customer_zip_code_prefix NOT IN (SELECT
#                                          geolocation_zip_code_prefix
#                                      FROM
#                                          geolocation)
# GROUP BY
#     customer_zip_code_prefix  -- use group by to eleminate duplicate values.
#
#
# )

# %%
# %%sql
# SELECT *
# FROM geolocation
# LIMIT 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [(1001, 'sao paulo', 'SP'),
#  (1002, 'sao paulo', 'SP'),
#  (1003, 'sao paulo', 'SP'),
#  (1004, 'sao paulo', 'SP'),
#  (1005, 'sao paulo', 'SP')]

# %%
# %%sql
# -- Check for values in customer table but missing in geolocation.
# SELECT
#     *
# FROM
#     customers
# WHERE
#     customer_zip_code_prefix not in (
#                                     SELECT
#                                         geolocation_zip_code_prefix
#                                     FROM
#                                         geolocation)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 0 rows affected.
# []

# %%
# %%sql
#
# ALTER TABLE customers
# ADD CONSTRAINT fk_name1
# FOREIGN KEY (customer_zip_code_prefix)
# REFERENCES geolocation(geolocation_zip_code_prefix)

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Sellers - Geolocation using zip_code_prefix</FONT>

# %%
# %%sql
# SELECT *
# FROM
#     sellers
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('0015a82c2db000af6aaaf3ae2ecb0532', 9080, 'santo andre', 'SP'),
#  ('001cca7ae9ae17fb1caed9dfb1094831', 29156, 'cariacica', 'ES'),
#  ('001e6ad469a905060d959994f1b41e4f', 24754, 'sao goncalo', 'RJ'),
#  ('002100f778ceb8431b7a1020ff7ab48f', 14405, 'franca', 'SP'),
#  ('003554e2dce176b5555353e4f3555ac8', 74565, 'goiania', 'GO')]

# %% [markdown]
# We had the same previous problem about data missing in the geolocation table. We'll add missing data from sellers into geolocation.

# %%
# %%sql
# INSERT INTO geolocation
# (
# SELECT
#     seller_zip_code_prefix,
#     MAX(seller_city) as seller_city,
#     MAX(seller_state) as seller_state
# FROM
#     SELLERS
# WHERE
#     seller_zip_code_prefix NOT IN (SELECT
#                                          geolocation_zip_code_prefix
#                                      FROM
#                                          geolocation)
# GROUP BY
#     seller_zip_code_prefix  -- use group by to eleminate duplicate values.
#
# )

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Customers</FONT> - <FONT color='grey'><FONT color='green'>Geolocation</FONT> </FONT><FONT color='grey'>relationship</FONT>

# %%
# %%sql
#
# ALTER TABLE sellers
# ADD CONSTRAINT fk_name2
# FOREIGN KEY (seller_zip_code_prefix)
# REFERENCES geolocation(geolocation_zip_code_prefix);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Customers - Orders using customer_id</FONT>

# %%
# %%sql
# SELECT *
# FROM orders
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('00010242fe8c5a6d1ba2dd792cb16214', '3ce436f183e68e07877b285a838db11a', 'delivered', '2017-09-13 08:59:02', '2017-09-13 09:45:35', '2017-09-19 18:34:16', '2017-09-20 23:43:48', '2017-09-29 00:00:00'),
#  ('00018f77f2f0320c557190d7a144bdd3', 'f6dd3ec061db4e3987629fe6b26e5cce', 'delivered', '2017-04-26 10:53:06', '2017-04-26 11:05:13', '2017-05-04 14:35:00', '2017-05-12 16:04:24', '2017-05-15 00:00:00'),
#  ('000229ec398224ef6ca0657da4fc703e', '6489ae5e4333f3693df5ad4372dab6d3', 'delivered', '2018-01-14 14:33:31', '2018-01-14 14:48:30', '2018-01-16 12:36:48', '2018-01-22 13:19:16', '2018-02-05 00:00:00'),
#  ('00024acbcdf0a6daa1e931b038114c75', 'd4eb9395c8c0431ee92fce09860c5a06', 'delivered', '2018-08-08 10:00:35', '2018-08-08 10:10:18', '2018-08-10 13:28:00', '2018-08-14 13:32:39', '2018-08-20 00:00:00'),
#  ('00042b26cf59d7ce69dfabb4e55b4fd9', '58dbd0b2d70206bf40e62cd34e84d795', 'delivered', '2017-02-04 13:57:51', '2017-02-04 14:10:13', '2017-02-16 09:46:09', '2017-03-01 16:42:31', '2017-03-17 00:00:00')]

# %%
# %%sql
#
# ALTER TABLE orders
# ADD CONSTRAINT fk_name3
# FOREIGN KEY (customer_id)
# REFERENCES customers(customer_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Sellers - Order_items using seller_id</FONT>

# %%
# %%sql
#
# SELECT *
# FROM order_items
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('00010242fe8c5a6d1ba2dd792cb16214', 1, '4244733e06e7ecb4970a6e2683c13e61', '48436dade18ac8b2bce089ec2a041202', '2017-09-19 09:45:35', Decimal('58.90'), Decimal('13.29'), 1),
#  ('00018f77f2f0320c557190d7a144bdd3', 1, 'e5f2d52b802189ee658865ca93d83a8f', 'dd7ddc04e1b6c2c614352b383efe2d36', '2017-05-03 11:05:13', Decimal('239.90'), Decimal('19.93'), 1),
#  ('000229ec398224ef6ca0657da4fc703e', 1, 'c777355d18b72b67abbeef9df44fd0fd', '5b51032eddd242adc84c38acab88f23d', '2018-01-18 14:48:30', Decimal('199.00'), Decimal('17.87'), 1),
#  ('00024acbcdf0a6daa1e931b038114c75', 1, '7634da152a4610f1595efa32f14722fc', '9d7a1d34a5052409006425275ba1c2b4', '2018-08-15 10:10:18', Decimal('12.99'), Decimal('12.79'), 1),
#  ('00042b26cf59d7ce69dfabb4e55b4fd9', 1, 'ac6c3623068f30de03045865e4e10089', 'df560393f3a51e74553ab94004ba5c87', '2017-02-13 13:57:51', Decimal('199.90'), Decimal('18.14'), 1)]

# %%
# %%sql
#
# ALTER TABLE order_items
# ADD CONSTRAINT fk_name4
# FOREIGN KEY (seller_id)
# REFERENCES sellers(seller_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Orders - Order_items using order_id</FONT>

# %%
# %%sql
# SELECT * FROM orders limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('00010242fe8c5a6d1ba2dd792cb16214', '3ce436f183e68e07877b285a838db11a', 'delivered', '2017-09-13 08:59:02', '2017-09-13 09:45:35', '2017-09-19 18:34:16', '2017-09-20 23:43:48', '2017-09-29 00:00:00'),
#  ('00018f77f2f0320c557190d7a144bdd3', 'f6dd3ec061db4e3987629fe6b26e5cce', 'delivered', '2017-04-26 10:53:06', '2017-04-26 11:05:13', '2017-05-04 14:35:00', '2017-05-12 16:04:24', '2017-05-15 00:00:00'),
#  ('000229ec398224ef6ca0657da4fc703e', '6489ae5e4333f3693df5ad4372dab6d3', 'delivered', '2018-01-14 14:33:31', '2018-01-14 14:48:30', '2018-01-16 12:36:48', '2018-01-22 13:19:16', '2018-02-05 00:00:00'),
#  ('00024acbcdf0a6daa1e931b038114c75', 'd4eb9395c8c0431ee92fce09860c5a06', 'delivered', '2018-08-08 10:00:35', '2018-08-08 10:10:18', '2018-08-10 13:28:00', '2018-08-14 13:32:39', '2018-08-20 00:00:00'),
#  ('00042b26cf59d7ce69dfabb4e55b4fd9', '58dbd0b2d70206bf40e62cd34e84d795', 'delivered', '2017-02-04 13:57:51', '2017-02-04 14:10:13', '2017-02-16 09:46:09', '2017-03-01 16:42:31', '2017-03-17 00:00:00')]

# %%
# %%sql
#
# ALTER TABLE order_items
# ADD CONSTRAINT fk_name5
# FOREIGN KEY (order_id)
# REFERENCES orders(order_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Products - Order_items using product_id</FONT>

# %%
# %%sql
# SELECT * FROM products limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('1e9e8ef04dbcff4541ed26657ea517e5', 'perfumaria', '40', '287', '1', '225', '16', '10', '14'),
#  ('3aa071139cb16b67ca9e5dea641aaa2f', 'artes', '44', '276', '1', '1000', '30', '18', '20'),
#  ('96bd76ec8810374ed1b65e291975717f', 'esporte_lazer', '46', '250', '1', '154', '18', '9', '15'),
#  ('cef67bcfe19066a932b7673e239eb23d', 'bebes', '27', '261', '1', '371', '26', '4', '26'),
#  ('9dc1a7de274444849c219cff195d0b71', 'utilidades_domesticas', '37', '402', '4', '625', '20', '17', '13')]

# %%
# %%sql
#
# ALTER TABLE order_items
# ADD CONSTRAINT fk_name6
# FOREIGN KEY (product_id)
# REFERENCES products(product_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Order payments - Orders using order_id</FONT>

# %%
# %%sql
#
# SELECT *
# FROM order_payments
# where order_id not in (SELECT order_id from orders);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 0 rows affected.
# []

# %%
# %%sql
#
# ALTER TABLE order_payments
# ADD CONSTRAINT fk_name7
# FOREIGN KEY (order_id)
# REFERENCES orders(order_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Order reviews - Orders using order_id</FONT>

# %%
# %%sql
#
# SELECT *
# FROM order_reviews
# WHERE order_id NOT IN (SELECT order_id from orders)
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 0 rows affected.
# []

# %%
# %%sql
#
#
# ALTER TABLE order_reviews
# ADD CONSTRAINT fk_name8
# FOREIGN KEY (order_id)
# REFERENCES orders(order_id);

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
# ## <FONT color='green'>Products - Orders using seller_id</FONT>

# %%
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 9 rows affected.
# [('category_translation',),
#  ('customers',),
#  ('geolocation',),
#  ('order_items',),
#  ('order_payments',),
#  ('order_reviews',),
#  ('orders',),
#  ('products',),
#  ('sellers',)]

# %%
# %%sql
# SELECT * FROM category_translation limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('agro_industria_e_comercio', 'agro_industry_and_commerce'),
#  ('alimentos', 'food'),
#  ('alimentos_bebidas', 'food_drink'),
#  ('artes', 'art'),
#  ('artes_e_artesanato', 'arts_and_craftmanship')]

# %%
# %%sql
# SELECT * FROM products limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 5 rows affected.
# [('00066f42aeeb9f3007548bb9d3f33c38', 'perfumaria', '53', '596', '6', '300', '20', '16', '16'),
#  ('00088930e925c41fd95ebfe695fd2655', 'automotivo', '56', '752', '4', '1225', '55', '10', '26'),
#  ('0009406fd7479715e4bef61dd91f2462', 'cama_mesa_banho', '50', '266', '2', '300', '45', '15', '35'),
#  ('000b8f95fcb9e0096488278317764d19', 'utilidades_domesticas', '25', '364', '3', '550', '19', '24', '12'),
#  ('000d9be29b5207b54e86aa1b1ac54872', 'relogios_presentes', '48', '613', '4', '250', '22', '11', '15')]

# %%
# %%sql
# SELECT DISTINCT(product_category_name)
# FROM products
# WHERE product_category_name not in (select product_category_name from category_translation)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/brazil
# 2 rows affected.
# [('pc_gamer',), ('portateis_cozinha_e_preparadores_de_alimentos',)]

# %%
# %%sql
# -- Insert missing values in the translation table.
# INSERT INTO category_translation
# VALUES
#     ('pc_gamer', 'pc_gamer'),
#     ('portateis_cozinha_e_preparadores_de_alimentos', 'portable_kitchen_food_preparators');

# %%
# %%sql
#
# ALTER TABLE products
# ADD CONSTRAINT fk_name9
# FOREIGN KEY (product_category_name)
# REFERENCES  category_translation(product_category_name);

# %% [markdown]
# # <font color='red'>Result Schema <font/>
#
# <img src="./pic_of_new_schema.jpg" alt="Desired Schema"/>
